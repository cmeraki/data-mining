# %%
from pytube import YouTube
from pydub import AudioSegment
import os

def download_audio_from_youtube(video_url, output_path):
    try:
        # Download video
        yt = YouTube(video_url)
        video_stream = yt.streams.filter(only_audio=True).first()
        download_path = video_stream.download(output_path=output_path)

        # Convert to MP3 using pydub
        audio = AudioSegment.from_file(download_path)
        mp3_path = os.path.splitext(download_path)[0] + '.mp3'
        audio.export(mp3_path, format="mp3")

        # Remove the original file
        os.remove(download_path)

        print(f"Downloaded and converted audio saved at: {mp3_path}")
    except Exception as e:
        print(f"An error occurred: {e}")

if __name__ == "__main__":
    video_url = "https://www.youtube.com/watch?v=6dKiEY0UOtA&t=5s"
    output_path = "test4.mp3"
    download_audio_from_youtube(video_url, output_path)
# Out:
# Downloaded and converted audio saved at: g:\Projects\AudioScraping\test4.mp3\I Visited the Worlds Busiest Train Station.mp3

# %%
#Importing the AudioSegment
from pydub import AudioSegment
from pydub.silence import split_on_silence

#Normalise apmplitude
def match_target_amplitude(aChunk, target_dBFS):
    ''' Normalize given audio chunk '''
    change_in_dBFS = target_dBFS - aChunk.dBFS
    return aChunk.apply_gain(change_in_dBFS)

# Load your audio.
song = AudioSegment.from_mp3("test2.mp3/test2.mp3")

#Chunk creation
thresh = float('-inf')
chunks = split_on_silence (song,min_silence_len = 500 ,silence_thresh = thresh)

# Process each chunk with your parameters
for i, chunk in enumerate(chunks):
    silence_chunk = AudioSegment.silent(duration=10)
    audio_chunk = silence_chunk + chunk + silence_chunk
    normalized_chunk = match_target_amplitude(audio_chunk, -20.0)

    print("Exporting chunk{0}.mp3.".format(i))
    normalized_chunk.export(
        "./output8/chunk{0}.mp3".format(i),
        bitrate = "192k",
        format = "mp3"
    )
# Out:
# Exporting chunk0.mp3.
# Exporting chunk1.mp3.
# Exporting chunk2.mp3.
# Exporting chunk3.mp3.
# Exporting chunk4.mp3.
# Exporting chunk5.mp3.
# Exporting chunk6.mp3.
# Exporting chunk7.mp3.
# Exporting chunk8.mp3.
# Exporting chunk9.mp3.
# Exporting chunk10.mp3.
# Exporting chunk11.mp3.
# Exporting chunk12.mp3.
# Exporting chunk13.mp3.
# Exporting chunk14.mp3.
# Exporting chunk15.mp3.
# Exporting chunk16.mp3.
# Exporting chunk17.mp3.
# Exporting chunk18.mp3.
# Exporting chunk19.mp3.
# Exporting chunk20.mp3.
# Exporting chunk21.mp3.
# Exporting chunk22.mp3.
# Exporting chunk23.mp3.
# Exporting chunk24.mp3.
# Exporting chunk25.mp3.
# Exporting chunk26.mp3.
# Exporting chunk27.mp3.
# Exporting chunk28.mp3.
# Exporting chunk29.mp3.
# Exporting chunk30.mp3.

# %%
from pydub import AudioSegment
import numpy as np
import os

def calculate_decibels(frame):
    # Convert audio frame to numpy array
    frame_array = np.array(frame.get_array_of_samples())
    # Calculate RMS (Root Mean Square) value
    rms = np.sqrt(np.mean(frame_array**2))
    # Convert RMS to decibels
    if rms > 0:
        decibels = 20 * np.log10(rms)
    else:
        decibels = -float('inf')  # -inf if there is complete silence
    return decibels

def get_decibel_readings(audio_file_path, frame_duration_ms=100):
    audio = AudioSegment.from_file(audio_file_path)
    duration_ms = len(audio)
    decibel_readings = []

    for start_ms in range(0, duration_ms, frame_duration_ms):
        end_ms = start_ms + frame_duration_ms
        frame = audio[start_ms:end_ms]
        decibels = calculate_decibels(frame)
        decibel_readings.append((start_ms, decibels))

    return decibel_readings

if __name__ == "__main__":
    audio_file_path = "test2.mp3/test2.mp3"
    frame_duration_ms = 500

    if not os.path.exists(audio_file_path):
        print("File does not exist.")
    else:
        readings = get_decibel_readings(audio_file_path, frame_duration_ms)
        for start_ms, decibels in readings:
            print(f"Time: {start_ms} ms, Decibels: {decibels:.2f} dB")
# Out:
# Time: 0 ms, Decibels: 27.00 dB
# Time: 500 ms, Decibels: -inf dB
# Time: 1000 ms, Decibels: 34.71 dB
# Time: 1500 ms, Decibels: 38.36 dB
# Time: 2000 ms, Decibels: 36.78 dB
# Time: 2500 ms, Decibels: 30.63 dB
# Time: 3000 ms, Decibels: 26.50 dB
# Time: 3500 ms, Decibels: 29.24 dB
# Time: 4000 ms, Decibels: 37.25 dB
# Time: 4500 ms, Decibels: 28.96 dB
# Time: 5000 ms, Decibels: 24.91 dB
# Time: 5500 ms, Decibels: 30.73 dB
# Time: 6000 ms, Decibels: 24.67 dB
# Time: 6500 ms, Decibels: 21.95 dB
# Time: 7000 ms, Decibels: 36.21 dB
# Time: 7500 ms, Decibels: 36.35 dB
# Time: 8000 ms, Decibels: 32.05 dB
# Time: 8500 ms, Decibels: 28.89 dB
# Time: 9000 ms, Decibels: -inf dB
# Time: 9500 ms, Decibels: 17.19 dB
# Time: 10000 ms, Decibels: 35.93 dB
# Time: 10500 ms, Decibels: 26.97 dB
# Time: 11000 ms, Decibels: 29.53 dB
# Time: 11500 ms, Decibels: 31.09 dB
# Time: 12000 ms, Decibels: 14.39 dB
# Time: 12500 ms, Decibels: 24.50 dB
# Time: 13000 ms, Decibels: 28.03 dB
# Time: 13500 ms, Decibels: 31.97 dB
# Time: 14000 ms, Decibels: 37.29 dB
# Time: 14500 ms, Decibels: 35.47 dB
# Time: 15000 ms, Decibels: 37.75 dB
# Time: 15500 ms, Decibels: 33.76 dB
# Time: 16000 ms, Decibels: 22.17 dB
# Time: 16500 ms, Decibels: 20.25 dB
# Time: 17000 ms, Decibels: 24.12 dB
# Time: 17500 ms, Decibels: 37.94 dB
# Time: 18000 ms, Decibels: 30.04 dB
# Time: 18500 ms, Decibels: 35.60 dB
# Time: 19000 ms, Decibels: 28.27 dB
# Time: 19500 ms, Decibels: 23.67 dB
# Time: 20000 ms, Decibels: 29.73 dB
# Time: 20500 ms, Decibels: 37.55 dB
# Time: 21000 ms, Decibels: 37.27 dB
# Time: 21500 ms, Decibels: 35.91 dB
# Time: 22000 ms, Decibels: 26.12 dB
# Time: 22500 ms, Decibels: 32.05 dB
# Time: 23000 ms, Decibels: 32.53 dB
# Time: 23500 ms, Decibels: 32.34 dB
# Time: 24000 ms, Decibels: 28.98 dB
# Time: 24500 ms, Decibels: 27.60 dB
# Time: 25000 ms, Decibels: 36.90 dB
# Time: 25500 ms, Decibels: 35.72 dB
# Time: 26000 ms, Decibels: 35.88 dB
# Time: 26500 ms, Decibels: 26.13 dB
# Time: 27000 ms, Decibels: 29.13 dB
# Time: 27500 ms, Decibels: 28.97 dB
# Time: 28000 ms, Decibels: 25.30 dB
# Time: 28500 ms, Decibels: 37.63 dB
# Time: 29000 ms, Decibels: 37.13 dB
# Time: 29500 ms, Decibels: 30.89 dB
# Time: 30000 ms, Decibels: 26.47 dB
# Time: 30500 ms, Decibels: 25.90 dB
# Time: 31000 ms, Decibels: 35.16 dB
# Time: 31500 ms, Decibels: 24.13 dB
# Time: 32000 ms, Decibels: 28.61 dB
# Time: 32500 ms, Decibels: 22.56 dB
# Time: 33000 ms, Decibels: 28.18 dB
# Time: 33500 ms, Decibels: 37.58 dB
# Time: 34000 ms, Decibels: 38.94 dB
# Time: 34500 ms, Decibels: 36.44 dB
# Time: 35000 ms, Decibels: 32.66 dB
# Time: 35500 ms, Decibels: 33.80 dB
# Time: 36000 ms, Decibels: 37.06 dB
# Time: 36500 ms, Decibels: 35.57 dB
# Time: 37000 ms, Decibels: 37.42 dB
# Time: 37500 ms, Decibels: 33.34 dB
# Time: 38000 ms, Decibels: 34.65 dB
# Time: 38500 ms, Decibels: -inf dB
# Time: 39000 ms, Decibels: 27.94 dB
# Time: 39500 ms, Decibels: 34.44 dB
# Time: 40000 ms, Decibels: 36.59 dB
# Time: 40500 ms, Decibels: 35.62 dB
# Time: 41000 ms, Decibels: 24.89 dB
# Time: 41500 ms, Decibels: 29.26 dB
# Time: 42000 ms, Decibels: 26.12 dB
# Time: 42500 ms, Decibels: 35.49 dB
# Time: 43000 ms, Decibels: 36.16 dB
# Time: 43500 ms, Decibels: -inf dB
# Time: 44000 ms, Decibels: 33.30 dB
# Time: 44500 ms, Decibels: 36.97 dB
# Time: 45000 ms, Decibels: 37.38 dB
# Time: 45500 ms, Decibels: 35.13 dB
# Time: 46000 ms, Decibels: 23.16 dB
# Time: 46500 ms, Decibels: 36.61 dB
# Time: 47000 ms, Decibels: 35.84 dB
# Time: 47500 ms, Decibels: 33.60 dB
# Time: 48000 ms, Decibels: 26.70 dB
# Time: 48500 ms, Decibels: 22.67 dB
# Time: 49000 ms, Decibels: 28.15 dB
# Time: 49500 ms, Decibels: 16.10 dB
# Time: 50000 ms, Decibels: 28.59 dB
# Time: 50500 ms, Decibels: 20.47 dB
# Time: 51000 ms, Decibels: 24.96 dB
# Time: 51500 ms, Decibels: 28.45 dB
# Time: 52000 ms, Decibels: 20.76 dB
# Time: 52500 ms, Decibels: 33.86 dB
# Time: 53000 ms, Decibels: 34.01 dB
# Time: 53500 ms, Decibels: 18.97 dB
# Time: 54000 ms, Decibels: 35.31 dB
# Time: 54500 ms, Decibels: 37.23 dB
# Time: 55000 ms, Decibels: 36.13 dB
# Time: 55500 ms, Decibels: 31.08 dB
# Time: 56000 ms, Decibels: 36.44 dB
# Time: 56500 ms, Decibels: 30.52 dB
# Time: 57000 ms, Decibels: 34.83 dB
# Time: 57500 ms, Decibels: -inf dB
# Time: 58000 ms, Decibels: 27.91 dB
# Time: 58500 ms, Decibels: 33.23 dB
# Time: 59000 ms, Decibels: 36.80 dB
# Time: 59500 ms, Decibels: 29.74 dB
# Time: 60000 ms, Decibels: 27.85 dB
# Time: 60500 ms, Decibels: 19.42 dB
# Time: 61000 ms, Decibels: 27.78 dB
# Time: 61500 ms, Decibels: 36.77 dB
# Time: 62000 ms, Decibels: 35.31 dB
# Time: 62500 ms, Decibels: 28.05 dB
# Time: 63000 ms, Decibels: 22.16 dB
# Time: 63500 ms, Decibels: 26.09 dB
# Time: 64000 ms, Decibels: 23.16 dB
# Time: 64500 ms, Decibels: 33.40 dB
# Time: 65000 ms, Decibels: 33.40 dB
# Time: 65500 ms, Decibels: 34.67 dB
# Time: 66000 ms, Decibels: 37.05 dB
# Time: 66500 ms, Decibels: 38.40 dB
# Time: 67000 ms, Decibels: 14.45 dB
# Time: 67500 ms, Decibels: 33.14 dB
# Time: 68000 ms, Decibels: 35.76 dB
# Time: 68500 ms, Decibels: 37.34 dB
# Time: 69000 ms, Decibels: 34.88 dB
# Time: 69500 ms, Decibels: 34.21 dB
# Time: 70000 ms, Decibels: -inf dB
# Time: 70500 ms, Decibels: 20.52 dB
# Time: 71000 ms, Decibels: 16.09 dB
# Time: 71500 ms, Decibels: -inf dB
# Time: 72000 ms, Decibels: 33.44 dB
# Time: 72500 ms, Decibels: 36.54 dB
# Time: 73000 ms, Decibels: 26.05 dB
# Time: 73500 ms, Decibels: 26.04 dB
# Time: 74000 ms, Decibels: 27.71 dB
# Time: 74500 ms, Decibels: -inf dB
# Time: 75000 ms, Decibels: 31.45 dB
# Time: 75500 ms, Decibels: 36.75 dB
# Time: 76000 ms, Decibels: 34.34 dB
# Time: 76500 ms, Decibels: 37.35 dB
# Time: 77000 ms, Decibels: 32.34 dB
# Time: 77500 ms, Decibels: 22.40 dB
# Time: 78000 ms, Decibels: 35.86 dB
# Time: 78500 ms, Decibels: 36.55 dB
# Time: 79000 ms, Decibels: 30.81 dB
# Time: 79500 ms, Decibels: 23.48 dB
# Time: 80000 ms, Decibels: 26.55 dB
# Time: 80500 ms, Decibels: 36.63 dB
# Time: 81000 ms, Decibels: 27.47 dB
# Time: 81500 ms, Decibels: 21.79 dB
# Time: 82000 ms, Decibels: 32.92 dB
# Time: 82500 ms, Decibels: 37.63 dB
# Time: 83000 ms, Decibels: 28.22 dB
# Time: 83500 ms, Decibels: 27.00 dB
# Time: 84000 ms, Decibels: 36.66 dB
# Time: 84500 ms, Decibels: 35.82 dB
# Time: 85000 ms, Decibels: 36.95 dB
# Time: 85500 ms, Decibels: 30.14 dB
# Time: 86000 ms, Decibels: 28.16 dB
# Time: 86500 ms, Decibels: 37.02 dB
# Time: 87000 ms, Decibels: 24.33 dB
# Time: 87500 ms, Decibels: 24.29 dB
# Time: 88000 ms, Decibels: 34.17 dB
# Time: 88500 ms, Decibels: 19.62 dB
# Time: 89000 ms, Decibels: 26.22 dB
# Time: 89500 ms, Decibels: 33.51 dB
# Time: 90000 ms, Decibels: 37.08 dB
# Time: 90500 ms, Decibels: 37.32 dB
# Time: 91000 ms, Decibels: 33.81 dB
# Time: 91500 ms, Decibels: 27.96 dB
# Time: 92000 ms, Decibels: -inf dB
# Time: 92500 ms, Decibels: 26.22 dB
# Time: 93000 ms, Decibels: 25.71 dB
# Time: 93500 ms, Decibels: 37.13 dB
# Time: 94000 ms, Decibels: 37.31 dB
# Time: 94500 ms, Decibels: 36.49 dB
# Time: 95000 ms, Decibels: 35.32 dB
# Time: 95500 ms, Decibels: 23.19 dB
# Time: 96000 ms, Decibels: -inf dB
# Time: 96500 ms, Decibels: 35.43 dB
# Time: 97000 ms, Decibels: 31.01 dB
# Time: 97500 ms, Decibels: -inf dB
# Time: 98000 ms, Decibels: 26.53 dB
# Time: 98500 ms, Decibels: 34.28 dB
# Time: 99000 ms, Decibels: 28.64 dB
# Time: 99500 ms, Decibels: -inf dB
# Time: 100000 ms, Decibels: -inf dB
# Time: 100500 ms, Decibels: 27.24 dB
# Time: 101000 ms, Decibels: 34.86 dB
# Time: 101500 ms, Decibels: 20.07 dB
# Time: 102000 ms, Decibels: 36.85 dB
# Time: 102500 ms, Decibels: 37.29 dB
# Time: 103000 ms, Decibels: 37.11 dB
# Time: 103500 ms, Decibels: 35.78 dB
# Time: 104000 ms, Decibels: 32.97 dB
# Time: 104500 ms, Decibels: -inf dB
# Time: 105000 ms, Decibels: 32.16 dB
# Time: 105500 ms, Decibels: 36.18 dB
# Time: 106000 ms, Decibels: 32.01 dB
# Time: 106500 ms, Decibels: 27.75 dB
# Time: 107000 ms, Decibels: 33.57 dB
# Time: 107500 ms, Decibels: 27.75 dB
# Time: 108000 ms, Decibels: 24.20 dB
# Time: 108500 ms, Decibels: 28.69 dB
# Time: 109000 ms, Decibels: 22.37 dB
# Time: 109500 ms, Decibels: 33.17 dB
# Time: 110000 ms, Decibels: 29.19 dB
# Time: 110500 ms, Decibels: 30.77 dB
# Time: 111000 ms, Decibels: 28.37 dB
# Time: 111500 ms, Decibels: 36.86 dB
# Time: 112000 ms, Decibels: 36.97 dB
# Time: 112500 ms, Decibels: 33.24 dB
# Time: 113000 ms, Decibels: 26.13 dB
# Time: 113500 ms, Decibels: 27.40 dB
# Time: 114000 ms, Decibels: 27.09 dB
# Time: 114500 ms, Decibels: 24.99 dB
# Time: 115000 ms, Decibels: 36.91 dB
# Time: 115500 ms, Decibels: 39.26 dB
# Time: 116000 ms, Decibels: 36.24 dB
# Time: 116500 ms, Decibels: 36.80 dB
# Time: 117000 ms, Decibels: 36.04 dB
# Time: 117500 ms, Decibels: 22.43 dB
# Time: 118000 ms, Decibels: 34.05 dB
# Time: 118500 ms, Decibels: 36.33 dB
# Time: 119000 ms, Decibels: 23.46 dB
# Time: 119500 ms, Decibels: 6.94 dB
# Time: 120000 ms, Decibels: 26.24 dB
# Time: 120500 ms, Decibels: -inf dB
# Time: 121000 ms, Decibels: 21.27 dB
# Time: 121500 ms, Decibels: 35.83 dB
# Time: 122000 ms, Decibels: 35.56 dB
# Time: 122500 ms, Decibels: 37.00 dB
# Time: 123000 ms, Decibels: 32.82 dB
# Time: 123500 ms, Decibels: 31.92 dB
# Time: 124000 ms, Decibels: 32.82 dB
# Time: 124500 ms, Decibels: -inf dB
# Time: 125000 ms, Decibels: 24.84 dB
# Time: 125500 ms, Decibels: 26.61 dB
# Time: 126000 ms, Decibels: 23.44 dB
# Time: 126500 ms, Decibels: 35.07 dB
# Time: 127000 ms, Decibels: 36.60 dB
# Time: 127500 ms, Decibels: 28.98 dB
# Time: 128000 ms, Decibels: 24.24 dB
# Time: 128500 ms, Decibels: 18.93 dB
# Time: 129000 ms, Decibels: 34.25 dB
# Time: 129500 ms, Decibels: 35.89 dB
# Time: 130000 ms, Decibels: 20.29 dB
# Time: 130500 ms, Decibels: 26.11 dB
# Time: 131000 ms, Decibels: 28.01 dB
# Time: 131500 ms, Decibels: 23.28 dB
# Time: 132000 ms, Decibels: 20.36 dB
# Time: 132500 ms, Decibels: 35.22 dB
# Time: 133000 ms, Decibels: -inf dB
# Time: 133500 ms, Decibels: 34.19 dB
# Time: 134000 ms, Decibels: -inf dB
# Time: 134500 ms, Decibels: 25.26 dB
# Time: 135000 ms, Decibels: 36.96 dB
# Time: 135500 ms, Decibels: 37.37 dB
# Time: 136000 ms, Decibels: 37.21 dB
# Time: 136500 ms, Decibels: 36.54 dB
# Time: 137000 ms, Decibels: 31.55 dB
# Time: 137500 ms, Decibels: 33.18 dB
# Time: 138000 ms, Decibels: 30.47 dB
# Time: 138500 ms, Decibels: 30.54 dB
# Time: 139000 ms, Decibels: 37.15 dB
# Time: 139500 ms, Decibels: 36.58 dB
# Time: 140000 ms, Decibels: -inf dB
# Time: 140500 ms, Decibels: 11.48 dB
# Time: 141000 ms, Decibels: 29.24 dB
# Time: 141500 ms, Decibels: 33.40 dB
# Time: 142000 ms, Decibels: 28.73 dB
# Time: 142500 ms, Decibels: -inf dB
# Time: 143000 ms, Decibels: 24.10 dB
# Time: 143500 ms, Decibels: 26.79 dB
# Time: 144000 ms, Decibels: 12.85 dB
# Time: 144500 ms, Decibels: 36.32 dB
# Time: 145000 ms, Decibels: 24.29 dB
# Time: 145500 ms, Decibels: 28.33 dB
# Time: 146000 ms, Decibels: 28.71 dB
# Time: 146500 ms, Decibels: 29.93 dB
# Time: 147000 ms, Decibels: -inf dB
# Time: 147500 ms, Decibels: 34.79 dB
# Time: 148000 ms, Decibels: 38.64 dB
# Time: 148500 ms, Decibels: 37.61 dB
# Time: 149000 ms, Decibels: 31.13 dB
# Time: 149500 ms, Decibels: 27.56 dB
# Time: 150000 ms, Decibels: 35.90 dB
# Time: 150500 ms, Decibels: 20.66 dB
# Time: 151000 ms, Decibels: -inf dB
# Time: 151500 ms, Decibels: 34.28 dB
# Time: 152000 ms, Decibels: 30.64 dB
# Time: 152500 ms, Decibels: -inf dB
# Time: 153000 ms, Decibels: -inf dB
# Time: 153500 ms, Decibels: 31.84 dB
# Time: 154000 ms, Decibels: 36.66 dB
# Time: 154500 ms, Decibels: 36.01 dB
# Time: 155000 ms, Decibels: 36.31 dB
# Time: 155500 ms, Decibels: 37.46 dB
# Time: 156000 ms, Decibels: 35.46 dB
# Time: 156500 ms, Decibels: 34.98 dB
# Time: 157000 ms, Decibels: 25.89 dB
# Time: 157500 ms, Decibels: 25.51 dB
# Time: 158000 ms, Decibels: 36.94 dB
# Time: 158500 ms, Decibels: 25.54 dB
# Time: 159000 ms, Decibels: -inf dB
# Time: 159500 ms, Decibels: 20.89 dB
# Time: 160000 ms, Decibels: 33.62 dB
# Time: 160500 ms, Decibels: -inf dB
# Time: 161000 ms, Decibels: -inf dB
# Time: 161500 ms, Decibels: -inf dB
# Time: 162000 ms, Decibels: 28.92 dB
# Time: 162500 ms, Decibels: 28.58 dB
# Time: 163000 ms, Decibels: 27.50 dB
# Time: 163500 ms, Decibels: 32.70 dB
# Time: 164000 ms, Decibels: 24.38 dB
# Time: 164500 ms, Decibels: 27.74 dB
# Time: 165000 ms, Decibels: 32.00 dB
# Time: 165500 ms, Decibels: 36.39 dB
# Time: 166000 ms, Decibels: 35.77 dB
# Time: 166500 ms, Decibels: 34.62 dB
# Time: 167000 ms, Decibels: 22.55 dB
# Time: 167500 ms, Decibels: 35.69 dB
# Time: 168000 ms, Decibels: 36.97 dB
# Time: 168500 ms, Decibels: 35.82 dB
# Time: 169000 ms, Decibels: 32.31 dB
# Time: 169500 ms, Decibels: 33.83 dB
# Time: 170000 ms, Decibels: 20.23 dB
# Time: 170500 ms, Decibels: 33.89 dB
# Time: 171000 ms, Decibels: 27.09 dB
# Time: 171500 ms, Decibels: 26.15 dB
# Time: 172000 ms, Decibels: 24.16 dB
# Time: 172500 ms, Decibels: 30.20 dB
# Time: 173000 ms, Decibels: -inf dB
# Time: 173500 ms, Decibels: 23.30 dB
# Time: 174000 ms, Decibels: 33.69 dB
# Time: 174500 ms, Decibels: 37.46 dB
# Time: 175000 ms, Decibels: 33.20 dB
# Time: 175500 ms, Decibels: 29.35 dB
# Time: 176000 ms, Decibels: 16.79 dB
# Time: 176500 ms, Decibels: 18.72 dB
# Time: 177000 ms, Decibels: 27.70 dB
# Time: 177500 ms, Decibels: 26.68 dB
# Time: 178000 ms, Decibels: 36.14 dB
# Time: 178500 ms, Decibels: 37.74 dB
# Time: 179000 ms, Decibels: 35.77 dB
# Time: 179500 ms, Decibels: 33.28 dB
# Time: 180000 ms, Decibels: 36.00 dB
# Time: 180500 ms, Decibels: 36.08 dB
# Time: 181000 ms, Decibels: 24.40 dB
# Time: 181500 ms, Decibels: 35.72 dB
# Time: 182000 ms, Decibels: 33.75 dB
# Time: 182500 ms, Decibels: 28.93 dB
# Time: 183000 ms, Decibels: 28.74 dB
# Time: 183500 ms, Decibels: 20.07 dB
# Time: 184000 ms, Decibels: 25.95 dB
# Time: 184500 ms, Decibels: 30.10 dB
# Time: 185000 ms, Decibels: 37.09 dB
# Time: 185500 ms, Decibels: 36.29 dB
# Time: 186000 ms, Decibels: 29.90 dB
# Time: 186500 ms, Decibels: 27.43 dB
# Time: 187000 ms, Decibels: -inf dB
# Time: 187500 ms, Decibels: 27.99 dB
# Time: 188000 ms, Decibels: 23.57 dB
# Time: 188500 ms, Decibels: 30.60 dB
# Time: 189000 ms, Decibels: 34.31 dB
# Time: 189500 ms, Decibels: 36.62 dB
# Time: 190000 ms, Decibels: 34.46 dB
# Time: 190500 ms, Decibels: 31.02 dB
# Time: 191000 ms, Decibels: 14.91 dB
# Time: 191500 ms, Decibels: 31.13 dB
# Time: 192000 ms, Decibels: 37.07 dB
# Time: 192500 ms, Decibels: 33.19 dB
# Time: 193000 ms, Decibels: 27.58 dB
# Time: 193500 ms, Decibels: 28.00 dB
# Time: 194000 ms, Decibels: 25.97 dB
# Time: 194500 ms, Decibels: 19.02 dB
# Time: 195000 ms, Decibels: 25.91 dB
# Time: 195500 ms, Decibels: 24.72 dB
# Time: 196000 ms, Decibels: 26.98 dB
# Time: 196500 ms, Decibels: 20.03 dB
# Time: 197000 ms, Decibels: 38.28 dB
# Time: 197500 ms, Decibels: 37.40 dB
# Time: 198000 ms, Decibels: 36.72 dB
# Time: 198500 ms, Decibels: 36.06 dB
# Time: 199000 ms, Decibels: 37.18 dB
# Time: 199500 ms, Decibels: 35.11 dB
# Time: 200000 ms, Decibels: 37.45 dB
# Time: 200500 ms, Decibels: 37.32 dB
# Time: 201000 ms, Decibels: 37.02 dB
# Time: 201500 ms, Decibels: 36.81 dB
# Time: 202000 ms, Decibels: 35.89 dB
# Time: 202500 ms, Decibels: 20.49 dB
# Time: 203000 ms, Decibels: 34.17 dB
# Time: 203500 ms, Decibels: 21.65 dB
# Time: 204000 ms, Decibels: 33.08 dB
# Time: 204500 ms, Decibels: 37.37 dB
# Time: 205000 ms, Decibels: 35.42 dB
# Time: 205500 ms, Decibels: 28.74 dB
# Time: 206000 ms, Decibels: 36.92 dB
# Time: 206500 ms, Decibels: 24.39 dB
# Time: 207000 ms, Decibels: 26.50 dB
# Time: 207500 ms, Decibels: 35.57 dB
# Time: 208000 ms, Decibels: 37.56 dB
# Time: 208500 ms, Decibels: 23.09 dB
# Time: 209000 ms, Decibels: 32.96 dB
# Time: 209500 ms, Decibels: 37.04 dB
# Time: 210000 ms, Decibels: 36.41 dB
# Time: 210500 ms, Decibels: 35.11 dB
# Time: 211000 ms, Decibels: 18.50 dB
# Time: 211500 ms, Decibels: 31.95 dB
# Time: 212000 ms, Decibels: 32.49 dB
# Time: 212500 ms, Decibels: 34.71 dB
# Time: 213000 ms, Decibels: 33.73 dB
# Time: 213500 ms, Decibels: 36.36 dB
# Time: 214000 ms, Decibels: -inf dB
# Time: 214500 ms, Decibels: 26.19 dB
# Time: 215000 ms, Decibels: 26.40 dB
# Time: 215500 ms, Decibels: 27.50 dB
# Time: 216000 ms, Decibels: 35.07 dB
# Time: 216500 ms, Decibels: 37.57 dB
# Time: 217000 ms, Decibels: 37.17 dB
# Time: 217500 ms, Decibels: 35.14 dB
# Time: 218000 ms, Decibels: 20.10 dB
# Time: 218500 ms, Decibels: 34.53 dB
# Time: 219000 ms, Decibels: 33.74 dB
# Time: 219500 ms, Decibels: 36.49 dB
# Time: 220000 ms, Decibels: 35.68 dB
# Time: 220500 ms, Decibels: 36.85 dB
# Time: 221000 ms, Decibels: 31.20 dB
# Time: 221500 ms, Decibels: 27.07 dB
# Time: 222000 ms, Decibels: 26.25 dB
# Time: 222500 ms, Decibels: 26.51 dB
# Time: 223000 ms, Decibels: 26.02 dB
# Time: 223500 ms, Decibels: 23.26 dB
# Time: 224000 ms, Decibels: 25.78 dB
# Time: 224500 ms, Decibels: 35.96 dB
# Time: 225000 ms, Decibels: 36.77 dB
# Time: 225500 ms, Decibels: 36.54 dB
# Time: 226000 ms, Decibels: 37.24 dB
# Time: 226500 ms, Decibels: 30.31 dB
# Time: 227000 ms, Decibels: 33.41 dB
# Time: 227500 ms, Decibels: 33.26 dB
# Time: 228000 ms, Decibels: 36.33 dB
# Time: 228500 ms, Decibels: 32.45 dB
# Time: 229000 ms, Decibels: 35.13 dB
# Time: 229500 ms, Decibels: 36.19 dB
# Time: 230000 ms, Decibels: 34.27 dB
# Time: 230500 ms, Decibels: 35.91 dB
# Time: 231000 ms, Decibels: 30.74 dB
# Time: 231500 ms, Decibels: 16.42 dB
# Time: 232000 ms, Decibels: 16.80 dB
# Time: 232500 ms, Decibels: 29.55 dB
# Time: 233000 ms, Decibels: 21.40 dB
# Time: 233500 ms, Decibels: 34.25 dB
# Time: 234000 ms, Decibels: 37.47 dB
# Time: 234500 ms, Decibels: 36.30 dB
# Time: 235000 ms, Decibels: 32.57 dB
# Time: 235500 ms, Decibels: 28.04 dB
# Time: 236000 ms, Decibels: 34.69 dB
# Time: 236500 ms, Decibels: 28.77 dB
# Time: 237000 ms, Decibels: 27.69 dB
# Time: 237500 ms, Decibels: 28.48 dB
# Time: 238000 ms, Decibels: 29.97 dB
# Time: 238500 ms, Decibels: 23.55 dB
# Time: 239000 ms, Decibels: 24.54 dB
# Time: 239500 ms, Decibels: 27.10 dB
# Time: 240000 ms, Decibels: 35.25 dB
# Time: 240500 ms, Decibels: 37.47 dB
# Time: 241000 ms, Decibels: 37.02 dB
# Time: 241500 ms, Decibels: 36.60 dB
# Time: 242000 ms, Decibels: 27.50 dB
# Time: 242500 ms, Decibels: 18.06 dB
# Time: 243000 ms, Decibels: -inf dB
# Time: 243500 ms, Decibels: 36.14 dB
# Time: 244000 ms, Decibels: 36.84 dB
# Time: 244500 ms, Decibels: 34.36 dB
# Time: 245000 ms, Decibels: 28.22 dB
# Time: 245500 ms, Decibels: 29.04 dB
# Time: 246000 ms, Decibels: 29.62 dB
# Time: 246500 ms, Decibels: 12.29 dB
# Time: 247000 ms, Decibels: -inf dB
# Time: 247500 ms, Decibels: 31.40 dB
# Time: 248000 ms, Decibels: 37.38 dB
# Time: 248500 ms, Decibels: 34.98 dB
# Time: 249000 ms, Decibels: 37.52 dB
# Time: 249500 ms, Decibels: 37.36 dB
# Time: 250000 ms, Decibels: 23.27 dB
# Time: 250500 ms, Decibels: 27.16 dB
# Time: 251000 ms, Decibels: -inf dB
# Time: 251500 ms, Decibels: 28.30 dB
# Time: 252000 ms, Decibels: 27.23 dB
# Time: 252500 ms, Decibels: 35.36 dB
# Time: 253000 ms, Decibels: 36.47 dB
# Time: 253500 ms, Decibels: 37.49 dB
# Time: 254000 ms, Decibels: 35.62 dB
# Time: 254500 ms, Decibels: 35.13 dB
# Time: 255000 ms, Decibels: 12.30 dB
# Time: 255500 ms, Decibels: 32.33 dB
# Time: 256000 ms, Decibels: 33.64 dB
# Time: 256500 ms, Decibels: 24.47 dB
# Time: 257000 ms, Decibels: 25.59 dB
# Time: 257500 ms, Decibels: 27.72 dB
# Time: 258000 ms, Decibels: 27.51 dB
# Time: 258500 ms, Decibels: 25.94 dB
# Time: 259000 ms, Decibels: 31.62 dB
# Time: 259500 ms, Decibels: 31.22 dB
# Time: 260000 ms, Decibels: 37.60 dB
# Time: 260500 ms, Decibels: 36.79 dB
# Time: 261000 ms, Decibels: 32.11 dB
# Time: 261500 ms, Decibels: 34.66 dB
# Time: 262000 ms, Decibels: 37.48 dB
# Time: 262500 ms, Decibels: 30.10 dB
# Time: 263000 ms, Decibels: 27.10 dB
# Time: 263500 ms, Decibels: 23.30 dB
# Time: 264000 ms, Decibels: 31.54 dB
# Time: 264500 ms, Decibels: 17.52 dB
# Time: 265000 ms, Decibels: 25.25 dB
# Time: 265500 ms, Decibels: 32.51 dB
# Time: 266000 ms, Decibels: 17.62 dB
# Time: 266500 ms, Decibels: -inf dB
# Time: 267000 ms, Decibels: 28.12 dB
# Time: 267500 ms, Decibels: 28.19 dB
# Time: 268000 ms, Decibels: 30.90 dB
# Time: 268500 ms, Decibels: 36.61 dB
# Time: 269000 ms, Decibels: 35.33 dB
# Time: 269500 ms, Decibels: 37.12 dB
# Time: 270000 ms, Decibels: 37.48 dB
# Time: 270500 ms, Decibels: 35.07 dB
# Time: 271000 ms, Decibels: 36.07 dB
# Time: 271500 ms, Decibels: 36.10 dB
# Time: 272000 ms, Decibels: 33.00 dB
# Time: 272500 ms, Decibels: 37.50 dB
# Time: 273000 ms, Decibels: 28.75 dB
# Time: 273500 ms, Decibels: 25.30 dB
# Time: 274000 ms, Decibels: 34.03 dB
# Time: 274500 ms, Decibels: 36.50 dB
# Time: 275000 ms, Decibels: 33.38 dB
# Time: 275500 ms, Decibels: 27.50 dB
# Time: 276000 ms, Decibels: 29.62 dB
# Time: 276500 ms, Decibels: 26.11 dB
# Time: 277000 ms, Decibels: 32.69 dB
# Time: 277500 ms, Decibels: 32.45 dB
# Time: 278000 ms, Decibels: 35.14 dB
# Time: 278500 ms, Decibels: 37.69 dB
# Time: 279000 ms, Decibels: 38.20 dB
# Time: 279500 ms, Decibels: 37.48 dB
# Time: 280000 ms, Decibels: 32.27 dB
# Time: 280500 ms, Decibels: 24.53 dB
# Time: 281000 ms, Decibels: -inf dB
# Time: 281500 ms, Decibels: 35.85 dB
# Time: 282000 ms, Decibels: 37.28 dB
# Time: 282500 ms, Decibels: 34.96 dB
# Time: 283000 ms, Decibels: 13.74 dB
# Time: 283500 ms, Decibels: 22.42 dB
# Time: 284000 ms, Decibels: 29.11 dB
# Time: 284500 ms, Decibels: 26.20 dB
# Time: 285000 ms, Decibels: 36.27 dB
# Time: 285500 ms, Decibels: 35.86 dB
# Time: 286000 ms, Decibels: 37.14 dB
# Time: 286500 ms, Decibels: 36.85 dB
# Time: 287000 ms, Decibels: 35.72 dB
# Time: 287500 ms, Decibels: 36.17 dB
# Time: 288000 ms, Decibels: 28.84 dB
# Time: 288500 ms, Decibels: 28.19 dB
# Time: 289000 ms, Decibels: 29.70 dB
# Time: 289500 ms, Decibels: 24.00 dB
# Time: 290000 ms, Decibels: 37.06 dB
# Time: 290500 ms, Decibels: 36.27 dB
# Time: 291000 ms, Decibels: 26.81 dB
# Time: 291500 ms, Decibels: 27.27 dB
# Time: 292000 ms, Decibels: 22.77 dB
# Time: 292500 ms, Decibels: 26.03 dB
# Time: 293000 ms, Decibels: 31.36 dB
# Time: 293500 ms, Decibels: 25.33 dB
# Time: 294000 ms, Decibels: 34.19 dB
# Time: 294500 ms, Decibels: 36.45 dB
# Time: 295000 ms, Decibels: 38.61 dB
# Time: 295500 ms, Decibels: 37.48 dB
# Time: 296000 ms, Decibels: 36.72 dB
# Time: 296500 ms, Decibels: 34.01 dB
# Time: 297000 ms, Decibels: 22.91 dB
# Time: 297500 ms, Decibels: 22.66 dB
# Time: 298000 ms, Decibels: 30.63 dB
# Time: 298500 ms, Decibels: 29.18 dB
# Time: 299000 ms, Decibels: 34.14 dB
# Time: 299500 ms, Decibels: 36.78 dB
# Time: 300000 ms, Decibels: 35.94 dB
# Time: 300500 ms, Decibels: 29.88 dB
# Time: 301000 ms, Decibels: 25.60 dB
# Time: 301500 ms, Decibels: 16.76 dB
# Time: 302000 ms, Decibels: 26.03 dB
# Time: 302500 ms, Decibels: 36.73 dB
# Time: 303000 ms, Decibels: 35.61 dB
# Time: 303500 ms, Decibels: 36.19 dB
# Time: 304000 ms, Decibels: 29.80 dB
# Time: 304500 ms, Decibels: 27.26 dB
# Time: 305000 ms, Decibels: 31.45 dB
# Time: 305500 ms, Decibels: 36.63 dB
# Time: 306000 ms, Decibels: 37.67 dB
# Time: 306500 ms, Decibels: 37.12 dB
# Time: 307000 ms, Decibels: 33.17 dB
# Time: 307500 ms, Decibels: 35.62 dB
# Time: 308000 ms, Decibels: 34.77 dB
# Time: 308500 ms, Decibels: -inf dB
# Time: 309000 ms, Decibels: 21.23 dB
# Time: 309500 ms, Decibels: 22.28 dB
# Time: 310000 ms, Decibels: -inf dB
# Time: 310500 ms, Decibels: 29.07 dB
# Time: 311000 ms, Decibels: 34.83 dB
# Time: 311500 ms, Decibels: 38.89 dB
# Time: 312000 ms, Decibels: 36.68 dB
# Time: 312500 ms, Decibels: 36.89 dB
# Time: 313000 ms, Decibels: 35.94 dB
# Time: 313500 ms, Decibels: 36.99 dB
# Time: 314000 ms, Decibels: 29.75 dB
# Time: 314500 ms, Decibels: 31.13 dB
# Time: 315000 ms, Decibels: 36.60 dB
# Time: 315500 ms, Decibels: 37.71 dB
# Time: 316000 ms, Decibels: 30.56 dB
# Time: 316500 ms, Decibels: 33.32 dB
# Time: 317000 ms, Decibels: 28.81 dB
# Time: 317500 ms, Decibels: 25.21 dB
# Time: 318000 ms, Decibels: 29.65 dB
# Time: 318500 ms, Decibels: 35.27 dB
# Time: 319000 ms, Decibels: 37.32 dB
# Time: 319500 ms, Decibels: 35.41 dB
# Time: 320000 ms, Decibels: 35.80 dB
# Time: 320500 ms, Decibels: 32.47 dB
# Time: 321000 ms, Decibels: 20.17 dB
# Time: 321500 ms, Decibels: 11.90 dB
# Time: 322000 ms, Decibels: 27.79 dB
# Time: 322500 ms, Decibels: 28.88 dB
# Time: 323000 ms, Decibels: 24.83 dB
# Time: 323500 ms, Decibels: 30.14 dB
# Time: 324000 ms, Decibels: 27.01 dB
# Time: 324500 ms, Decibels: 24.88 dB
# Time: 325000 ms, Decibels: 31.39 dB
# Time: 325500 ms, Decibels: 37.76 dB
# Time: 326000 ms, Decibels: 35.31 dB
# Time: 326500 ms, Decibels: 6.53 dB
# Time: 327000 ms, Decibels: 22.89 dB
# Time: 327500 ms, Decibels: 20.27 dB
# Time: 328000 ms, Decibels: 28.71 dB
# Time: 328500 ms, Decibels: 27.83 dB
# Time: 329000 ms, Decibels: 23.08 dB
# Time: 329500 ms, Decibels: 25.10 dB
# Time: 330000 ms, Decibels: 23.92 dB
# Time: 330500 ms, Decibels: 3.80 dB
# Time: 331000 ms, Decibels: -inf dB
# Time: 331500 ms, Decibels: -inf dB
# Time: 332000 ms, Decibels: 7.93 dB
# Time: 332500 ms, Decibels: 26.25 dB
# Time: 333000 ms, Decibels: 27.86 dB
# Time: 333500 ms, Decibels: 22.72 dB
# Time: 334000 ms, Decibels: 28.10 dB
# Time: 334500 ms, Decibels: 9.58 dB
# Time: 335000 ms, Decibels: 26.89 dB
# Time: 335500 ms, Decibels: 24.37 dB
# Time: 336000 ms, Decibels: 27.95 dB
# Time: 336500 ms, Decibels: -inf dB
# Time: 337000 ms, Decibels: 24.49 dB
# Time: 337500 ms, Decibels: 30.39 dB
# Time: 338000 ms, Decibels: 30.31 dB
# Time: 338500 ms, Decibels: 31.68 dB
# Time: 339000 ms, Decibels: 7.33 dB
# Time: 339500 ms, Decibels: -inf dB
# Time: 340000 ms, Decibels: -inf dB
# Time: 340500 ms, Decibels: -inf dB
# Time: 341000 ms, Decibels: -inf dB
# Time: 341500 ms, Decibels: -inf dB
# Time: 342000 ms, Decibels: -inf dB
# Time: 342500 ms, Decibels: -inf dB
# Time: 343000 ms, Decibels: -inf dB
# Time: 343500 ms, Decibels: -inf dB
# Time: 344000 ms, Decibels: 23.09 dB
# Time: 344500 ms, Decibels: 32.00 dB
# Time: 345000 ms, Decibels: 30.90 dB
# Time: 345500 ms, Decibels: -inf dB
# Time: 346000 ms, Decibels: 31.24 dB
# Time: 346500 ms, Decibels: 3.72 dB
# Time: 347000 ms, Decibels: -inf dB
# Time: 347500 ms, Decibels: -inf dB
# Time: 348000 ms, Decibels: 4.46 dB
# Time: 348500 ms, Decibels: 14.11 dB
# Time: 349000 ms, Decibels: 31.15 dB
# Time: 349500 ms, Decibels: -inf dB
# Time: 350000 ms, Decibels: 22.02 dB
# Time: 350500 ms, Decibels: 26.51 dB
# Time: 351000 ms, Decibels: -inf dB
# Time: 351500 ms, Decibels: -inf dB
# Time: 352000 ms, Decibels: 7.97 dB
# Time: 352500 ms, Decibels: 18.58 dB
# Time: 353000 ms, Decibels: 27.67 dB
# Time: 353500 ms, Decibels: 27.25 dB
# Time: 354000 ms, Decibels: 9.51 dB
# Time: 354500 ms, Decibels: -8.66 dB
# Time: 355000 ms, Decibels: 24.13 dB
# Time: 355500 ms, Decibels: -inf dB
# Time: 356000 ms, Decibels: 26.98 dB
# Time: 356500 ms, Decibels: 25.22 dB
# Time: 357000 ms, Decibels: 5.16 dB
# Time: 357500 ms, Decibels: 3.89 dB
# Time: 358000 ms, Decibels: 8.57 dB
# Time: 358500 ms, Decibels: 27.75 dB
# Time: 359000 ms, Decibels: 26.38 dB
# Time: 359500 ms, Decibels: 12.39 dB
# Time: 360000 ms, Decibels: 30.22 dB
# Time: 360500 ms, Decibels: -0.73 dB
# Time: 361000 ms, Decibels: -inf dB
# Time: 361500 ms, Decibels: 3.87 dB
# Time: 362000 ms, Decibels: -inf dB
# Time: 362500 ms, Decibels: -inf dB
# Time: 363000 ms, Decibels: 23.64 dB
# Time: 363500 ms, Decibels: 28.21 dB
# Time: 364000 ms, Decibels: 23.73 dB
# Time: 364500 ms, Decibels: -0.21 dB
# Time: 365000 ms, Decibels: -inf dB
# Time: 365500 ms, Decibels: -inf dB
# Time: 366000 ms, Decibels: 6.09 dB
# Time: 366500 ms, Decibels: -inf dB
# Time: 367000 ms, Decibels: 25.66 dB
# Time: 367500 ms, Decibels: 21.13 dB
# Time: 368000 ms, Decibels: 26.44 dB
# Time: 368500 ms, Decibels: 29.13 dB
# Time: 369000 ms, Decibels: 23.28 dB
# Time: 369500 ms, Decibels: 24.99 dB
# Time: 370000 ms, Decibels: 29.70 dB
# Time: 370500 ms, Decibels: 8.59 dB
# Time: 371000 ms, Decibels: -inf dB
# Time: 371500 ms, Decibels: -inf dB
# Time: 372000 ms, Decibels: 25.82 dB
# Time: 372500 ms, Decibels: 22.96 dB
# Time: 373000 ms, Decibels: -inf dB
# Time: 373500 ms, Decibels: 26.62 dB
# Time: 374000 ms, Decibels: -inf dB
# Time: 374500 ms, Decibels: 28.50 dB
# Time: 375000 ms, Decibels: 22.96 dB
# Time: 375500 ms, Decibels: -0.22 dB
# Time: 376000 ms, Decibels: 23.62 dB
# Time: 376500 ms, Decibels: 29.48 dB
# Time: 377000 ms, Decibels: 29.29 dB
# Time: 377500 ms, Decibels: 24.36 dB
# Time: 378000 ms, Decibels: 26.04 dB
# Time: 378500 ms, Decibels: -inf dB
# Time: 379000 ms, Decibels: 6.94 dB
# Time: 379500 ms, Decibels: 23.35 dB
# Time: 380000 ms, Decibels: -inf dB
# Time: 380500 ms, Decibels: -inf dB
# Time: 381000 ms, Decibels: 24.18 dB
# Time: 381500 ms, Decibels: 19.88 dB
# Time: 382000 ms, Decibels: 29.44 dB
# Time: 382500 ms, Decibels: -8.57 dB
# Time: 383000 ms, Decibels: -inf dB
# Time: 383500 ms, Decibels: -inf dB
# Time: 384000 ms, Decibels: 13.64 dB
# Time: 384500 ms, Decibels: 24.51 dB
# Time: 385000 ms, Decibels: 27.36 dB
# Time: 385500 ms, Decibels: -inf dB
# Time: 386000 ms, Decibels: 30.92 dB
# Time: 386500 ms, Decibels: 23.98 dB
# Time: 387000 ms, Decibels: 27.45 dB
# Time: 387500 ms, Decibels: 31.71 dB
# Time: 388000 ms, Decibels: -inf dB
# Time: 388500 ms, Decibels: 4.81 dB
# Time: 389000 ms, Decibels: 10.01 dB
# Time: 389500 ms, Decibels: 24.05 dB
# Time: 390000 ms, Decibels: 31.79 dB
# Time: 390500 ms, Decibels: 28.54 dB
# Time: 391000 ms, Decibels: 35.39 dB
# Time: 391500 ms, Decibels: 20.67 dB
# Time: 392000 ms, Decibels: 23.75 dB
# Time: 392500 ms, Decibels: 28.62 dB
# Time: 393000 ms, Decibels: 5.55 dB
# Time: 393500 ms, Decibels: -inf dB
# Time: 394000 ms, Decibels: 8.55 dB
# Time: 394500 ms, Decibels: 25.80 dB
# Time: 395000 ms, Decibels: -inf dB
# Time: 395500 ms, Decibels: 25.40 dB
# Time: 396000 ms, Decibels: 25.83 dB
# Time: 396500 ms, Decibels: 32.43 dB
# Time: 397000 ms, Decibels: 34.60 dB
# Time: 397500 ms, Decibels: 18.60 dB
# Time: 398000 ms, Decibels: 23.35 dB
# Time: 398500 ms, Decibels: 29.70 dB
# Time: 399000 ms, Decibels: 6.70 dB
# Time: 399500 ms, Decibels: -inf dB
# Time: 400000 ms, Decibels: -inf dB
# Time: 400500 ms, Decibels: 23.18 dB
# Time: 401000 ms, Decibels: 24.58 dB
# Time: 401500 ms, Decibels: 20.79 dB
# Time: 402000 ms, Decibels: 20.82 dB
# Time: 402500 ms, Decibels: 25.38 dB
# Time: 403000 ms, Decibels: -inf dB
# Time: 403500 ms, Decibels: 9.07 dB
# Time: 404000 ms, Decibels: 22.93 dB
# Time: 404500 ms, Decibels: -inf dB
# Time: 405000 ms, Decibels: 22.74 dB
# Time: 405500 ms, Decibels: 28.59 dB
# Time: 406000 ms, Decibels: 19.33 dB
# Time: 406500 ms, Decibels: 26.85 dB
# Time: 407000 ms, Decibels: 20.88 dB
# Time: 407500 ms, Decibels: 27.06 dB
# Time: 408000 ms, Decibels: 22.90 dB
# Time: 408500 ms, Decibels: -inf dB
# Time: 409000 ms, Decibels: -2.41 dB
# Time: 409500 ms, Decibels: 14.20 dB
# Time: 410000 ms, Decibels: 22.12 dB
# Time: 410500 ms, Decibels: 32.46 dB
# Time: 411000 ms, Decibels: 34.68 dB
# Time: 411500 ms, Decibels: 29.66 dB
# Time: 412000 ms, Decibels: 21.73 dB
# Time: 412500 ms, Decibels: -inf dB
# Time: 413000 ms, Decibels: 20.50 dB
# Time: 413500 ms, Decibels: 30.91 dB
# Time: 414000 ms, Decibels: -12.86 dB
# Time: 414500 ms, Decibels: 33.83 dB
# Time: 415000 ms, Decibels: 14.83 dB
# Time: 415500 ms, Decibels: 28.26 dB
# Time: 416000 ms, Decibels: 28.55 dB
# Time: 416500 ms, Decibels: 28.24 dB
# Time: 417000 ms, Decibels: 0.73 dB
# Time: 417500 ms, Decibels: 7.66 dB
# Time: 418000 ms, Decibels: 26.12 dB
# Time: 418500 ms, Decibels: 18.91 dB
# Time: 419000 ms, Decibels: 21.67 dB
# Time: 419500 ms, Decibels: 34.79 dB
# Time: 420000 ms, Decibels: 27.80 dB
# Time: 420500 ms, Decibels: 19.74 dB
# Time: 421000 ms, Decibels: 22.51 dB
# Time: 421500 ms, Decibels: 22.59 dB
# Time: 422000 ms, Decibels: 29.66 dB
# Time: 422500 ms, Decibels: -inf dB
# Time: 423000 ms, Decibels: -inf dB
# Time: 423500 ms, Decibels: 25.40 dB
# Time: 424000 ms, Decibels: 27.23 dB
# Time: 424500 ms, Decibels: 28.94 dB
# Time: 425000 ms, Decibels: 28.18 dB
# Time: 425500 ms, Decibels: 25.34 dB
# Time: 426000 ms, Decibels: -inf dB
# Time: 426500 ms, Decibels: 7.75 dB
# Time: 427000 ms, Decibels: 27.57 dB
# Time: 427500 ms, Decibels: 26.48 dB
# Time: 428000 ms, Decibels: 12.85 dB
# Time: 428500 ms, Decibels: -inf dB
# Time: 429000 ms, Decibels: 28.22 dB
# Time: 429500 ms, Decibels: 9.52 dB
# Time: 430000 ms, Decibels: 19.66 dB
# Time: 430500 ms, Decibels: 31.39 dB
# Time: 431000 ms, Decibels: 18.02 dB
# Time: 431500 ms, Decibels: -inf dB
# Time: 432000 ms, Decibels: 27.16 dB
# Time: 432500 ms, Decibels: 20.62 dB
# Time: 433000 ms, Decibels: 25.88 dB
# Time: 433500 ms, Decibels: 9.50 dB
# Time: 434000 ms, Decibels: 23.12 dB
# Time: 434500 ms, Decibels: -inf dB
# Time: 435000 ms, Decibels: -inf dB
# Time: 435500 ms, Decibels: 28.04 dB
# Time: 436000 ms, Decibels: 26.97 dB
# Time: 436500 ms, Decibels: 20.63 dB
# Time: 437000 ms, Decibels: 28.39 dB
# Time: 437500 ms, Decibels: -3.64 dB
# Time: 438000 ms, Decibels: -inf dB
# Time: 438500 ms, Decibels: -inf dB
# Time: 439000 ms, Decibels: -inf dB
# Time: 439500 ms, Decibels: -inf dB
# Time: 440000 ms, Decibels: -inf dB
# Time: 440500 ms, Decibels: 30.73 dB
# Time: 441000 ms, Decibels: 26.90 dB
# Time: 441500 ms, Decibels: 15.13 dB
# Time: 442000 ms, Decibels: 22.17 dB
# Time: 442500 ms, Decibels: -inf dB
# Time: 443000 ms, Decibels: 20.40 dB
# Time: 443500 ms, Decibels: 17.65 dB
# Time: 444000 ms, Decibels: 21.58 dB
# Time: 444500 ms, Decibels: -inf dB
# Time: 445000 ms, Decibels: 28.09 dB
# Time: 445500 ms, Decibels: 29.02 dB
# Time: 446000 ms, Decibels: -inf dB
# Time: 446500 ms, Decibels: -inf dB
# Time: 447000 ms, Decibels: -inf dB
# Time: 447500 ms, Decibels: 30.19 dB
# Time: 448000 ms, Decibels: 23.05 dB
# Time: 448500 ms, Decibels: 26.22 dB
# Time: 449000 ms, Decibels: 29.58 dB
# Time: 449500 ms, Decibels: 31.71 dB
# Time: 450000 ms, Decibels: -10.92 dB
# Time: 450500 ms, Decibels: 21.09 dB
# Time: 451000 ms, Decibels: 30.16 dB
# Time: 451500 ms, Decibels: -inf dB
# Time: 452000 ms, Decibels: 14.69 dB
# Time: 452500 ms, Decibels: 24.78 dB
# Time: 453000 ms, Decibels: -inf dB
# Time: 453500 ms, Decibels: 29.20 dB
# Time: 454000 ms, Decibels: 22.63 dB
# Time: 454500 ms, Decibels: 29.27 dB
# Time: 455000 ms, Decibels: 25.58 dB
# Time: 455500 ms, Decibels: -inf dB
# Time: 456000 ms, Decibels: 20.35 dB
# Time: 456500 ms, Decibels: -inf dB
# Time: 457000 ms, Decibels: 24.82 dB
# Time: 457500 ms, Decibels: -inf dB
# Time: 458000 ms, Decibels: 23.41 dB
# Time: 458500 ms, Decibels: 32.49 dB
# Time: 459000 ms, Decibels: 30.57 dB
# Time: 459500 ms, Decibels: -inf dB
# Time: 460000 ms, Decibels: 24.50 dB
# Time: 460500 ms, Decibels: 28.94 dB
# Time: 461000 ms, Decibels: 23.35 dB
# Time: 461500 ms, Decibels: -inf dB
# Time: 462000 ms, Decibels: 25.86 dB
# Time: 462500 ms, Decibels: 18.90 dB
# Time: 463000 ms, Decibels: 30.56 dB
# Time: 463500 ms, Decibels: 31.36 dB
# Time: 464000 ms, Decibels: -43.43 dB
# Time: 464500 ms, Decibels: -inf dB
# Time: 465000 ms, Decibels: -16.41 dB
# Time: 465500 ms, Decibels: 29.48 dB
# Time: 466000 ms, Decibels: 16.93 dB
# Time: 466500 ms, Decibels: -inf dB
# Time: 467000 ms, Decibels: 28.13 dB
# Time: 467500 ms, Decibels: 23.94 dB
# Time: 468000 ms, Decibels: 24.17 dB
# Time: 468500 ms, Decibels: 25.55 dB
# Time: 469000 ms, Decibels: 23.85 dB
# Time: 469500 ms, Decibels: 26.55 dB
# Time: 470000 ms, Decibels: 27.74 dB
# Time: 470500 ms, Decibels: -inf dB
# Time: 471000 ms, Decibels: 22.11 dB
# Time: 471500 ms, Decibels: 30.30 dB
# Time: 472000 ms, Decibels: 29.77 dB
# Time: 472500 ms, Decibels: 22.19 dB
# Time: 473000 ms, Decibels: 22.55 dB
# Time: 473500 ms, Decibels: 16.26 dB
# Time: 474000 ms, Decibels: -inf dB
# Time: 474500 ms, Decibels: 21.94 dB
# Time: 475000 ms, Decibels: 21.60 dB
# Time: 475500 ms, Decibels: 32.82 dB
# Time: 476000 ms, Decibels: 19.94 dB
# Time: 476500 ms, Decibels: 24.44 dB
# Time: 477000 ms, Decibels: -inf dB
# Time: 477500 ms, Decibels: 27.47 dB
# Time: 478000 ms, Decibels: -inf dB
# Time: 478500 ms, Decibels: 18.89 dB
# Time: 479000 ms, Decibels: 29.21 dB
# Time: 479500 ms, Decibels: 18.45 dB
# Time: 480000 ms, Decibels: 21.36 dB
# Time: 480500 ms, Decibels: 32.22 dB
# Time: 481000 ms, Decibels: 20.81 dB
# Time: 481500 ms, Decibels: 21.01 dB
# Time: 482000 ms, Decibels: 23.81 dB
# Time: 482500 ms, Decibels: -inf dB
# Time: 483000 ms, Decibels: 21.31 dB
# Time: 483500 ms, Decibels: -inf dB
# Time: 484000 ms, Decibels: 18.50 dB
# Time: 484500 ms, Decibels: 32.41 dB
# Time: 485000 ms, Decibels: 34.27 dB
# Time: 485500 ms, Decibels: 28.29 dB
# Time: 486000 ms, Decibels: 27.30 dB
# Time: 486500 ms, Decibels: 18.35 dB
# Time: 487000 ms, Decibels: 28.87 dB
# Time: 487500 ms, Decibels: 30.52 dB
# Time: 488000 ms, Decibels: 30.58 dB
# Time: 488500 ms, Decibels: 27.04 dB
# Time: 489000 ms, Decibels: 33.13 dB
# Time: 489500 ms, Decibels: 26.05 dB
# Time: 490000 ms, Decibels: 18.26 dB
# Time: 490500 ms, Decibels: -inf dB
# Time: 491000 ms, Decibels: 20.91 dB
# Time: 491500 ms, Decibels: 29.70 dB
# Time: 492000 ms, Decibels: 21.18 dB
# Time: 492500 ms, Decibels: 27.71 dB
# Time: 493000 ms, Decibels: 24.62 dB
# Time: 493500 ms, Decibels: 17.25 dB
# Time: 494000 ms, Decibels: 25.22 dB
# Time: 494500 ms, Decibels: -inf dB
# Time: 495000 ms, Decibels: -inf dB
# Time: 495500 ms, Decibels: 29.80 dB
# Time: 496000 ms, Decibels: 28.82 dB
# Time: 496500 ms, Decibels: -inf dB
# Time: 497000 ms, Decibels: 28.55 dB
# Time: 497500 ms, Decibels: 25.25 dB
# Time: 498000 ms, Decibels: 33.17 dB
# Time: 498500 ms, Decibels: 25.65 dB
# Time: 499000 ms, Decibels: -inf dB
# Time: 499500 ms, Decibels: -inf dB
# Time: 500000 ms, Decibels: 23.27 dB
# Time: 500500 ms, Decibels: 32.52 dB
# Time: 501000 ms, Decibels: 33.61 dB
# Time: 501500 ms, Decibels: 28.28 dB
# Time: 502000 ms, Decibels: 21.21 dB
# Time: 502500 ms, Decibels: -inf dB
# Time: 503000 ms, Decibels: 25.52 dB
# Time: 503500 ms, Decibels: 24.59 dB
# Time: 504000 ms, Decibels: 27.39 dB
# Time: 504500 ms, Decibels: 18.18 dB
# Time: 505000 ms, Decibels: 28.50 dB
# Time: 505500 ms, Decibels: 30.24 dB
# Time: 506000 ms, Decibels: 27.10 dB
# Time: 506500 ms, Decibels: 19.30 dB
# Time: 507000 ms, Decibels: 28.52 dB
# Time: 507500 ms, Decibels: 34.62 dB
# Time: 508000 ms, Decibels: -inf dB
# Time: 508500 ms, Decibels: -inf dB
# Time: 509000 ms, Decibels: 26.14 dB
# Time: 509500 ms, Decibels: 25.33 dB
# Time: 510000 ms, Decibels: 23.71 dB
# Time: 510500 ms, Decibels: 29.88 dB
# Time: 511000 ms, Decibels: 25.52 dB
# Time: 511500 ms, Decibels: 26.36 dB
# Time: 512000 ms, Decibels: 28.72 dB
# Time: 512500 ms, Decibels: 29.26 dB
# Time: 513000 ms, Decibels: 24.85 dB
# Time: 513500 ms, Decibels: 27.01 dB
# C:\Users\user1\AppData\Local\Temp\ipykernel_14152\4091899628.py:9: RuntimeWarning: invalid value encountered in sqrt
#   rms = np.sqrt(np.mean(frame_array**2))

# %%
from pydub import AudioSegment

def split_mp3(file_path, split_length=3000):
    # Load the MP3 file
    audio = AudioSegment.from_mp3(file_path)
    
    # Calculate the number of splits
    total_length = len(audio)
    start = 0
    
    # Split the audio every `split_length` milliseconds
    for i in range(0, total_length, split_length):
        split_audio = audio[start:start+split_length]
        split_filename = f"output6/split_part_{i//split_length}.mp3"
        split_audio.export(split_filename, format="mp3")
        start += split_length

# Example usage
split_mp3("test1.mp3/test1.mp3")

# %%
##USING GOOGLE API CLIENT DISCOVERY

from googleapiclient.discovery import build
from googleapiclient.http import MediaIoBaseDownload
import io

# Initialize the YouTube API client
youtube = build('youtube', 'v3', developerKey='YOUR_API_KEY')

def download_captions(caption_id):
    request = youtube.captions().download(
        id=caption_id,
        tfmt='srt'  # Specifies the format of the caption file to download, e.g., 'srt' for SubRip subtitle format.
    )
    
    fh = io.BytesIO()
    downloader = MediaIoBaseDownload(fh, request)
    done = False
    while not done:
        status, done = downloader.next_chunk()
    
    fh.seek(0)
    return fh.read().decode('utf-8')

# Example usage
caption_id = 'YOUR_CAPTION_ID' 
transcript = download_captions(caption_id)
print(transcript)

# %% [markdown]
# Using the Youtube Transcript API

# %%
from pytube import YouTube

def download_video(url, path='videos/'):
    yt = YouTube(url)
    video = yt.streams.filter(file_extension='mp4').first()
    video.download(output_path=path, filename='video.mp4')

# %%
from moviepy.editor import *

def extract_audio(video_path, audio_path='audio/'):
    video = VideoFileClip(video_path)
    audio = video.audio
    audio.write_audiofile(audio_path + 'audio.mp3')

# %%
from youtube_transcript_api import YouTubeTranscriptApi

def download_transcript(video_id):
    transcript_list = YouTubeTranscriptApi.list_transcripts(video_id)
    transcript = transcript_list.find_transcript(['en'])  # Assuming English transcripts
    return transcript.fetch()

# %% [markdown]
# #USING YT - DLP LIBRARY

# %%
import yt_dlp

def download_srt(video_url):
    ydl_opts = {
        'writesubtitles': True,  # Write subtitle file
        'subtitlesformat': 'srt',  # Subtitles format (srt/vtt/ass/...)
        'subtitleslangs': ['en'],  # Languages of subtitles to download (use ['all'] to download all available subtitles)
        'outtmpl': '%(id)s.%(ext)s',  # Save file using the video ID
    }

    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        ydl.download([video_url])

# Example usage
video_url = 'https://www.youtube.com/watch?v=QoKpQMJnBHY&ab_channel=SpeakEnglishSmartly'
download_srt(video_url)
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=QoKpQMJnBHY&ab_channel=SpeakEnglishSmartly
# [youtube] QoKpQMJnBHY: Downloading webpage
# [youtube] QoKpQMJnBHY: Downloading ios player API JSON
# [youtube] QoKpQMJnBHY: Downloading player 5352eb4f
# [youtube] QoKpQMJnBHY: Downloading m3u8 information
# [info] QoKpQMJnBHY: Downloading 1 format(s): 616+251
# [info] There are no subtitles for the requested languages
# [hlsnative] Downloading m3u8 manifest
# [hlsnative] Total fragments: 93
# [download] Destination: QoKpQMJnBHY.f616.mp4
# [download] 100% of   73.11MiB in 00:00:36 at 2.00MiB/s
# [download] Destination: QoKpQMJnBHY.f251.webm
# [download] 100% of    7.09MiB in 00:00:01 at 4.23MiB/s
# [Merger] Merging formats into "QoKpQMJnBHY.webm"
# Deleting original file QoKpQMJnBHY.f616.mp4 (pass -k to keep)
# Deleting original file QoKpQMJnBHY.f251.webm (pass -k to keep)

# %% [markdown]
# YT-DLP FOR A YOUTUBE CHANNEL

# %%
import subprocess
import yt_dlp

def get_video_ids(channel_url):
    command = ['yt-dlp', '--get-id', channel_url]
    result = subprocess.run(command, stdout=subprocess.PIPE, text=True)
    video_ids = result.stdout.strip().split('\n')
    return video_ids

def download_srt(video_id):
    ydl_opts = {
        'writesubtitles': True,
        'subtitlesformat': 'srt',
        'subtitleslangs': ['en-CA','en'],
        'outtmpl': '%(id)s.%(ext)s',
    }

    video_url = f'https://www.youtube.com/watch?v={video_id}'
    '''with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        ydl.download([video_url])'''

# Example usage
channel_url = 'https://www.youtube.com/c/NotJustBikes/videos'
video_ids = get_video_ids(channel_url)

for video_id in video_ids:
    download_srt(video_id)

# %% [markdown]
# YT-DLP REFINED ---- 5/7/24

# %%
import yt_dlp

def extract_transcript(video_url):
    ydl_opts = {
        'skip_download': True,  # Skip downloading the video
        'writeautomaticsub': True,  # Download automatic subtitles
        'subtitleslangs': ['en','en-CA'],  # Preferred subtitle language
        'subtitlesformat': 'vtt',  # Subtitle format
        'outtmpl': 'subtitles/%(id)s.%(ext)s',  # Output template
        'quiet': True,  # Suppress verbose output
    }

    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        ydl.download([video_url])

# Example usage
video_url = 'https://youtu.be/6dKiEY0UOtA'
extract_transcript(video_url)

# %% [markdown]
# SUBTITLE METADATA

# %%
import yt_dlp

def get_subtitle_info(video_url):
    ydl_opts = {
        'skip_download': True,  # We only want to extract info
        'writesubtitles': True,
        'subtitleslangs': [],  # Leave empty to get all available languages
    }

    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        info = ydl.extract_info(video_url, download=False)
        return info

def print_subtitle_info(info):
    if 'subtitles' in info:
        print(f"Subtitles available for {info['title']} ({info['id']}):")
        for lang, subtitles in info['subtitles'].items():
            print(f"  Language: {lang}")
            for subtitle in subtitles:
                print(f"    Format: {subtitle['ext']}")
                print(f"    URL: {subtitle['url']}")
    else:
        print(f"No subtitles available for {info['title']} ({info['id']}).")

if __name__ == "__main__":
    video_url = "https://youtu.be/6dKiEY0UOtA"
    info = get_subtitle_info(video_url)
    print_subtitle_info(info)
# Out:
# [youtube] Extracting URL: https://youtu.be/6dKiEY0UOtA
# [youtube] 6dKiEY0UOtA: Downloading webpage
# [youtube] 6dKiEY0UOtA: Downloading ios player API JSON
# [youtube] 6dKiEY0UOtA: Downloading m3u8 information
# [info] 6dKiEY0UOtA: Downloading subtitles: en-CA
# Subtitles available for I Visited the World's Busiest Train Station (6dKiEY0UOtA):
#   Language: en-CA
#     Format: json3
#     URL: https://www.youtube.com/api/timedtext?v=6dKiEY0UOtA&ei=MY2HZv7XK762z7sPhtCO2AQ&caps=asr&opi=112496729&xoaf=5&hl=en&ip=0.0.0.0&ipbits=0&expire=1720184737&sparams=ip%2Cipbits%2Cexpire%2Cv%2Cei%2Ccaps%2Copi%2Cxoaf&signature=7FBE3C624F3F7847E415ADB2A5B5A888000400AE.7116F0FEA90FEF76FFD969168FF86890A24C4800&key=yt8&lang=en-CA&fmt=json3
#     Format: srv1
#     URL: https://www.youtube.com/api/timedtext?v=6dKiEY0UOtA&ei=MY2HZv7XK762z7sPhtCO2AQ&caps=asr&opi=112496729&xoaf=5&hl=en&ip=0.0.0.0&ipbits=0&expire=1720184737&sparams=ip%2Cipbits%2Cexpire%2Cv%2Cei%2Ccaps%2Copi%2Cxoaf&signature=7FBE3C624F3F7847E415ADB2A5B5A888000400AE.7116F0FEA90FEF76FFD969168FF86890A24C4800&key=yt8&lang=en-CA&fmt=srv1
#     Format: srv2
#     URL: https://www.youtube.com/api/timedtext?v=6dKiEY0UOtA&ei=MY2HZv7XK762z7sPhtCO2AQ&caps=asr&opi=112496729&xoaf=5&hl=en&ip=0.0.0.0&ipbits=0&expire=1720184737&sparams=ip%2Cipbits%2Cexpire%2Cv%2Cei%2Ccaps%2Copi%2Cxoaf&signature=7FBE3C624F3F7847E415ADB2A5B5A888000400AE.7116F0FEA90FEF76FFD969168FF86890A24C4800&key=yt8&lang=en-CA&fmt=srv2
#     Format: srv3
#     URL: https://www.youtube.com/api/timedtext?v=6dKiEY0UOtA&ei=MY2HZv7XK762z7sPhtCO2AQ&caps=asr&opi=112496729&xoaf=5&hl=en&ip=0.0.0.0&ipbits=0&expire=1720184737&sparams=ip%2Cipbits%2Cexpire%2Cv%2Cei%2Ccaps%2Copi%2Cxoaf&signature=7FBE3C624F3F7847E415ADB2A5B5A888000400AE.7116F0FEA90FEF76FFD969168FF86890A24C4800&key=yt8&lang=en-CA&fmt=srv3
#     Format: ttml
#     URL: https://www.youtube.com/api/timedtext?v=6dKiEY0UOtA&ei=MY2HZv7XK762z7sPhtCO2AQ&caps=asr&opi=112496729&xoaf=5&hl=en&ip=0.0.0.0&ipbits=0&expire=1720184737&sparams=ip%2Cipbits%2Cexpire%2Cv%2Cei%2Ccaps%2Copi%2Cxoaf&signature=7FBE3C624F3F7847E415ADB2A5B5A888000400AE.7116F0FEA90FEF76FFD969168FF86890A24C4800&key=yt8&lang=en-CA&fmt=ttml
#     Format: vtt
#     URL: https://www.youtube.com/api/timedtext?v=6dKiEY0UOtA&ei=MY2HZv7XK762z7sPhtCO2AQ&caps=asr&opi=112496729&xoaf=5&hl=en&ip=0.0.0.0&ipbits=0&expire=1720184737&sparams=ip%2Cipbits%2Cexpire%2Cv%2Cei%2Ccaps%2Copi%2Cxoaf&signature=7FBE3C624F3F7847E415ADB2A5B5A888000400AE.7116F0FEA90FEF76FFD969168FF86890A24C4800&key=yt8&lang=en-CA&fmt=vtt

# %% [markdown]
# EXTRACTING THE TIMESTAMPS INTO AN ARRAY

# %%
import re
from datetime import datetime, timedelta

def extract_timestamps_from_vtt(filename):
    # Regular expression to match timestamps
    timestamp_regex = r'(\d{2}:\d{2}:\d{2}\.\d{3}) --> (\d{2}:\d{2}:\d{2}\.\d{3})'
    
    timestamps = []
    
    with open(filename, 'r', encoding='utf-8') as file:
        content = file.read()
        matches = re.findall(timestamp_regex, content)
        for start, end in matches:
            # Parse timestamps and convert to milliseconds
            start_ms = int(timedelta(hours=int(start[0:2]), minutes=int(start[3:5]), seconds=int(start[6:8]), milliseconds=int(start[9:])).total_seconds() * 1000)
            end_ms = int(timedelta(hours=int(end[0:2]), minutes=int(end[3:5]), seconds=int(end[6:8]), milliseconds=int(end[9:])).total_seconds() * 1000)
            timestamps.append((start_ms, end_ms))
    
    return timestamps

# Example usage
filename = 'subtitles/6dKiEY0UOtA.en.vtt'
timestamps = extract_timestamps_from_vtt(filename)
arr = timestamps
print(timestamps)
# Out:
# [(320, 2709), (2709, 2719), (2719, 4510), (4510, 4520), (4520, 6869), (6869, 6879), (6879, 8750), (8750, 8760), (8760, 10589), (10589, 10599), (10599, 12310), (12310, 12320), (12320, 15589), (15589, 15599), (15599, 17590), (17590, 17600), (17600, 19510), (19510, 19520), (19520, 20990), (20990, 21000), (21000, 22349), (22349, 22359), (22359, 24349), (24349, 24359), (24359, 26349), (26349, 26359), (26359, 29990), (29990, 30000), (30000, 31790), (31790, 31800), (31800, 34430), (34430, 34440), (34440, 37270), (37270, 37280), (37280, 39229), (39229, 39239), (39239, 42110), (42110, 42120), (42120, 43630), (43630, 43640), (43640, 45470), (45470, 45480), (45480, 47229), (47229, 47239), (47239, 50750), (50750, 50760), (50760, 52869), (52869, 52879), (52879, 54990), (54990, 55000), (55000, 57910), (57910, 57920), (57920, 59950), (59950, 59960), (59960, 62150), (62150, 62160), (62160, 64069), (64069, 64080), (64080, 66030), (66030, 66040), (66040, 73030), (73030, 73040), (73040, 74950), (74950, 74960), (74960, 77149), (77149, 77159), (77159, 79429), (79429, 79439), (79439, 81789), (81789, 81799), (81799, 84270), (84270, 84280), (84280, 85950), (85950, 85960), (85960, 87910), (87910, 87920), (87920, 89910), (89910, 89920), (89920, 91910), (91910, 91920), (91920, 94830), (94830, 94840), (94840, 97550), (97550, 97560), (97560, 99550), (99550, 99560), (99560, 101510), (101510, 101520), (101520, 104230), (104230, 104240), (104240, 106190), (106190, 106200), (106200, 108590), (108590, 108600), (108600, 111109), (111109, 111119), (111119, 113590), (113590, 113600), (113600, 115630), (115630, 115640), (115640, 117510), (117510, 117520), (117520, 120149), (120149, 120159), (120159, 122590), (122590, 122600), (122600, 124149), (124149, 124159), (124159, 126429), (126429, 126439), (126439, 128229), (128229, 128239), (128239, 130710), (130710, 130720), (130720, 132510), (132510, 132520), (132520, 135030), (135030, 135040), (135040, 137390), (137390, 137400), (137400, 139470), (139470, 139480), (139480, 142229), (142229, 142239), (142239, 144470), (144470, 144480), (144480, 146830), (146830, 146840), (146840, 149430), (149430, 149440), (149440, 151910), (151910, 151920), (151920, 154110), (154110, 154120), (154120, 155830), (155830, 155840), (155840, 158550), (158550, 158560), (158560, 160750), (160750, 160760), (160760, 162790), (162790, 162800), (162800, 164630), (164630, 164640), (164640, 166229), (166229, 166239), (166239, 168430), (168430, 168440), (168440, 170589), (170589, 170599), (170599, 172830), (172830, 172840), (172840, 175149), (175149, 175159), (175159, 177110), (177110, 177120), (177120, 179149), (179149, 179159), (179159, 180790), (180790, 180800), (180800, 182309), (182309, 182319), (182319, 184309), (184309, 184319), (184319, 186229), (186229, 186239), (186239, 187830), (187830, 187840), (187840, 190270), (190270, 190280), (190280, 192910), (192910, 192920), (192920, 195430), (195430, 195440), (195440, 197630), (197630, 197640), (197640, 200030), (200030, 200040), (200040, 201949), (201949, 201959), (201959, 203550), (203550, 203560), (203560, 205430), (205430, 205440), (205440, 207190), (207190, 207200), (207200, 209149), (209149, 209159), (209159, 210670), (210670, 210680), (210680, 212270), (212270, 212280), (212280, 214270), (214270, 214280), (214280, 215750), (215750, 215760), (215760, 217350), (217350, 217360), (217360, 219229), (219229, 219239), (219239, 221550), (221550, 221560), (221560, 223670), (223670, 223680), (223680, 225589), (225589, 225599), (225599, 226550), (226550, 226560), (226560, 228390), (228390, 228400), (228400, 229710), (229710, 229720), (229720, 231789), (231789, 231799), (231799, 234509), (234509, 234519), (234519, 236110), (236110, 236120), (236120, 237550), (237550, 237560), (237560, 239390), (239390, 239400), (239400, 240630), (240630, 240640), (240640, 243270), (243270, 243280), (243280, 245069), (245069, 245079), (245079, 247509), (247509, 247519), (247519, 248949), (248949, 248959), (248959, 25039 ...

# %%
def combine_timestamps(timestamps):
    combined_timestamps = []
    i = 0
    while i < len(timestamps) - 6:
        combined_timestamps.append((timestamps[i][0], timestamps[i + 6][1]))
        i += 7
    while i < len(timestamps):
        combined_timestamps.append(timestamps[i])
        i += 1

    return combined_timestamps

combined_timestamps = combine_timestamps(arr)
print(combined_timestamps)
len(combined_timestamps)
# Out:
# [(320, 8750), (8750, 15599), (15599, 22349), (22349, 30000), (30000, 39229), (39229, 45480), (45480, 54990), (54990, 62160), (62160, 74950), (74950, 81799), (81799, 89910), (89910, 97560), (97560, 106190), (106190, 113600), (113600, 122590), (122590, 128239), (128239, 137390), (137390, 144480), (144480, 154110), (154110, 160760), (160760, 168430), (168430, 175159), (175159, 182309), (182309, 187840), (187840, 197630), (197630, 203560), (203560, 210670), (210670, 215760), (215760, 223670), (223670, 228400), (228400, 236110), (236110, 240640), (240640, 248949), (248949, 255000), (255000, 262069), (262069, 269680), (269680, 277629), (277629, 284120), (284120, 292189), (292189, 298720), (298720, 307469), (307469, 313880), (313880, 321830), (321830, 327960), (327960, 337830), (337830, 344360), (344360, 352550), (352550, 358960), (358960, 367110), (367110, 372639), (372639, 380270), (380270, 385919), (385919, 394110), (394110, 399880), (399880, 410110), (410110, 416240), (416240, 425510), (425510, 432160), (432160, 441550), (441550, 448560), (448560, 456510), (456510, 463400), (463400, 471790), (471790, 478319), (478319, 486189), (486189, 493039), (493039, 501070), (501070, 507240), (507240, 515909), (515909, 523000), (523000, 531590), (531590, 537519), (537519, 546509), (546509, 553680), (553680, 561310), (561310, 567440), (567440, 576590), (576590, 582160), (582160, 591470), (591470, 598839), (598839, 608110), (608110, 616120), (616120, 623750), (623750, 630160), (630160, 639030), (639030, 647120), (647120, 655550), (655550, 661320), (661320, 668590), (668590, 674240), (674240, 682629), (682629, 687680), (687680, 695230), (695230, 702600), (702600, 710870), (710870, 715240), (715240, 723670), (723670, 729279), (729279, 737189), (737189, 744160), (744160, 753670), (753670, 758959), (758959, 766069), (766069, 772399), (772399, 778870), (778870, 785600), (785600, 794350), (794350, 802199), (802199, 811509), (811509, 818279), (818279, 826069), (826069, 832959), (832959, 840790), (840790, 846639), (846639, 856350), (856350, 862199), (862199, 869430), (869430, 876000), (876000, 884470), (884470, 890720), (890720, 898990), (898990, 906480), (906480, 915389), (915389, 920639), (920639, 927710), (927710, 934600), (934600, 942949), (942949, 948839), (948839, 957990), (957990, 964639), (964639, 974150), (974150, 980839), (980839, 990990), (990990, 999880), (999880, 1007910), (1007910, 1014279), (1014279, 1021790), (1021790, 1027439), (1027439, 1035069), (1035069, 1041919), (1041919, 1050070), (1050070, 1055679), (1055679, 1063350), (1063350, 1070120), (1070120, 1078990), (1078990, 1085919), (1085919, 1093789), (1093789, 1099679), (1099679, 1108549), (1108549, 1113720), (1113720, 1123149), (1123149, 1129440), (1129440, 1138430), (1138430, 1144039), (1144039, 1152110), (1152110, 1157440), (1157440, 1167070), (1167070, 1173240), (1173240, 1180430), (1180430, 1187840), (1187840, 1196029), (1196029, 1202280), (1202280, 1211669), (1211669, 1218760), (1218760, 1226270), (1226270, 1233120), (1233120, 1241590), (1241590, 1248880), (1248880, 1258710), (1258710, 1266720), (1266720, 1277559)]
# 171

# %% [markdown]
# AUDIO SEGMENTATION USING TIMESTAMPS

# %%
from pydub import AudioSegment
import os

# Example timestamps and files (start and end times in milliseconds)
timestamps = {
    'test4.mp3/test4.mp3': combined_timestamps}

def chunk_audio_files(timestamps, output_folder):
    
    for file, chunks in timestamps.items():
        audio = AudioSegment.from_file(file)
        for i, (start, end) in enumerate(chunks):
            # Slice the audio segment for the given start and end times
            chunk = audio[start:end]
            # Include the output folder in the chunk filename
            chunk_filename = os.path.join(output_folder, f"{os.path.basename(file).rsplit('.', 1)[0]}_chunk{i}.mp3")
            chunk.export(chunk_filename, format="mp3")
            print(f"Exported {chunk_filename}")

# Specify the output folder
output_folder = 'output10'
chunk_audio_files(timestamps, output_folder)
# Out:
# Exported output10\test4_chunk0.mp3
# Exported output10\test4_chunk1.mp3
# Exported output10\test4_chunk2.mp3
# Exported output10\test4_chunk3.mp3
# Exported output10\test4_chunk4.mp3
# Exported output10\test4_chunk5.mp3
# Exported output10\test4_chunk6.mp3
# Exported output10\test4_chunk7.mp3
# Exported output10\test4_chunk8.mp3
# Exported output10\test4_chunk9.mp3
# Exported output10\test4_chunk10.mp3
# Exported output10\test4_chunk11.mp3
# Exported output10\test4_chunk12.mp3
# Exported output10\test4_chunk13.mp3
# Exported output10\test4_chunk14.mp3
# Exported output10\test4_chunk15.mp3
# Exported output10\test4_chunk16.mp3
# Exported output10\test4_chunk17.mp3
# Exported output10\test4_chunk18.mp3
# Exported output10\test4_chunk19.mp3
# Exported output10\test4_chunk20.mp3
# Exported output10\test4_chunk21.mp3
# Exported output10\test4_chunk22.mp3
# Exported output10\test4_chunk23.mp3
# Exported output10\test4_chunk24.mp3
# Exported output10\test4_chunk25.mp3
# Exported output10\test4_chunk26.mp3
# Exported output10\test4_chunk27.mp3
# Exported output10\test4_chunk28.mp3
# Exported output10\test4_chunk29.mp3
# Exported output10\test4_chunk30.mp3
# Exported output10\test4_chunk31.mp3
# Exported output10\test4_chunk32.mp3
# Exported output10\test4_chunk33.mp3
# Exported output10\test4_chunk34.mp3
# Exported output10\test4_chunk35.mp3
# Exported output10\test4_chunk36.mp3
# Exported output10\test4_chunk37.mp3
# Exported output10\test4_chunk38.mp3
# Exported output10\test4_chunk39.mp3
# Exported output10\test4_chunk40.mp3
# Exported output10\test4_chunk41.mp3
# Exported output10\test4_chunk42.mp3
# Exported output10\test4_chunk43.mp3
# Exported output10\test4_chunk44.mp3
# Exported output10\test4_chunk45.mp3
# Exported output10\test4_chunk46.mp3
# Exported output10\test4_chunk47.mp3
# Exported output10\test4_chunk48.mp3
# Exported output10\test4_chunk49.mp3
# Exported output10\test4_chunk50.mp3
# Exported output10\test4_chunk51.mp3
# Exported output10\test4_chunk52.mp3
# Exported output10\test4_chunk53.mp3
# Exported output10\test4_chunk54.mp3
# Exported output10\test4_chunk55.mp3
# Exported output10\test4_chunk56.mp3
# Exported output10\test4_chunk57.mp3
# Exported output10\test4_chunk58.mp3
# Exported output10\test4_chunk59.mp3
# Exported output10\test4_chunk60.mp3
# Exported output10\test4_chunk61.mp3
# Exported output10\test4_chunk62.mp3
# Exported output10\test4_chunk63.mp3
# Exported output10\test4_chunk64.mp3
# Exported output10\test4_chunk65.mp3
# Exported output10\test4_chunk66.mp3
# Exported output10\test4_chunk67.mp3
# Exported output10\test4_chunk68.mp3
# Exported output10\test4_chunk69.mp3
# Exported output10\test4_chunk70.mp3
# Exported output10\test4_chunk71.mp3
# Exported output10\test4_chunk72.mp3
# Exported output10\test4_chunk73.mp3
# Exported output10\test4_chunk74.mp3
# Exported output10\test4_chunk75.mp3
# Exported output10\test4_chunk76.mp3
# Exported output10\test4_chunk77.mp3
# Exported output10\test4_chunk78.mp3
# Exported output10\test4_chunk79.mp3
# Exported output10\test4_chunk80.mp3
# Exported output10\test4_chunk81.mp3
# Exported output10\test4_chunk82.mp3
# Exported output10\test4_chunk83.mp3
# Exported output10\test4_chunk84.mp3
# Exported output10\test4_chunk85.mp3
# Exported output10\test4_chunk86.mp3
# Exported output10\test4_chunk87.mp3
# Exported output10\test4_chunk88.mp3
# Exported output10\test4_chunk89.mp3
# Exported output10\test4_chunk90.mp3
# Exported output10\test4_chunk91.mp3
# Exported output10\test4_chunk92.mp3
# Exported output10\test4_chunk93.mp3
# Exported output10\test4_chunk94.mp3
# Exported output10\test4_chunk95.mp3
# Exported output10\test4_chunk96.mp3
# Exported output10\test4_chunk97.mp3
# Exported output10\test4_chunk98.mp3
# Exported output10\test4_chunk99.mp3
# Exported output10\test4_chunk100.mp3
# Exported output10\test4_chunk101.mp3
# Exported output10\test4_chunk102.mp3
# Exported output10\test4_chunk103.mp3
# Exported output10\test4_chunk104.mp3
# Exported output10\test4_chunk105.mp3
# Exported output10\test4_chunk106.mp3
# Exported output10\test4_chunk107.mp3
# Exported output10\test4_chunk108.mp3
# Exported output10\test4_chunk109.mp3
# Exported output10\test4_chunk110.mp3
# Exported output10\test4_chunk111.mp3
# Exported output10\test4_chunk112.mp3
# Exported output10\test4_chunk113.mp3
# Exported output10\test4_chunk114.mp3
# Exported output10\test4_chunk115.mp3
# Exported output10\test4_chunk116.mp3
# Exported output10\test4_chunk117.mp3
# Exported output10\test4_chunk118.mp3
# Exported output10\test4_chunk119.mp3
# Exported output10\test4_chunk120.mp3
# Exported output10\test4_chunk121.mp3
# Exported output10\test4_chunk122.mp3
# Exported output10\test4_chunk123.mp3
# Exported output10\test4_chunk124.mp3
# Exported output10\test4_chunk125.mp3
# Exported output10\test4_chunk126.mp3
# Exported output10\test4_chunk127.mp3
# Exported output10\test4_chunk128.mp3
# Exported output10\test4_chunk129.mp3
# Exported output10\test4_chunk130.mp3
# Exported output10\test4_chunk131.mp3
# Exported output10\test4_chunk132.mp3
# Exported output10\test4_chunk133.mp3
# Exported output10\test4_chunk134.mp3
# Exported output10\test4_chunk135.mp3
# Exported output10\test4_chunk136.mp3
# Exported output10\test4_chunk137.mp3
# Exported output10\test4_chunk138.mp3
# Exported output10\test4_chunk139.mp3
# Exported output10\test4_chunk140.mp3
# Exported output10\test4_chunk141.mp3
# Exported output10\test4_chunk142.mp3
# Exported output10\test4_chunk143.mp3
# Exported output10\test4_chunk144.mp3
# Exported output10\test4_chunk145.mp3
# Exported output10\test4_chunk146.mp3
# Exported output10\test4_chunk147.mp3
# Exported output10\test4_chunk148.mp3
# Exported output10\test4_chunk149.mp3
# Exported output10\test4_chunk150.mp3
# Exported output10\test4_chunk151.mp3
# Exported output10\test4_chunk152.mp3
# Exported output10\test4_chunk153.mp3
# Exported output10\test4_chunk154.mp3
# Exported output10\test4_chunk155.mp3
# Exported output10\test4_chunk156.mp3
# Exported output10\test4_chunk157.mp3
# Exported output10\test4_chunk158.mp3
# Exported output10\test4_chunk159.mp3
# Exported output10\test4_chunk160.mp3
# Exported output10\test4_chunk161.mp3
# Exported output10\test4_chunk162.mp3
# Exported output10\test4_chunk163.mp3
# Exported output10\test4_chunk164.mp3
# Exported output10\test4_chunk165.mp3
# Exported output10\test4_chunk166.mp3
# Exported output10\test4_chunk167.mp3
# Exported output10\test4_chunk168.mp3
# Exported output10\test4_chunk169.mp3
# Exported output10\test4_chunk170.mp3

# %%
def milliseconds_to_time_format(milliseconds):
    # Calculate hours, minutes, seconds and milliseconds
    hours = milliseconds // (1000 * 60 * 60)
    milliseconds_remaining = milliseconds % (1000 * 60 * 60)
    minutes = milliseconds_remaining // (1000 * 60)
    milliseconds_remaining %= (1000 * 60)
    seconds = milliseconds_remaining // 1000
    milliseconds_remaining %= 1000
    
    # Format the time string
    time_format = f"{hours:02}:{minutes:02}:{seconds:02}:{milliseconds_remaining:03}"
    
    return time_format

time_format = []
for i in combined_timestamps:
    start_format = milliseconds_to_time_format(i[0])
    end_format = milliseconds_to_time_format(i[1])
    time_format.append((start_format, end_format))

print(time_format)
# Out:
# [('00:00:00:320', '00:00:08:750'), ('00:00:08:750', '00:00:15:599'), ('00:00:15:599', '00:00:22:349'), ('00:00:22:349', '00:00:30:000'), ('00:00:30:000', '00:00:39:229'), ('00:00:39:229', '00:00:45:480'), ('00:00:45:480', '00:00:54:990'), ('00:00:54:990', '00:01:02:160'), ('00:01:02:160', '00:01:14:950'), ('00:01:14:950', '00:01:21:799'), ('00:01:21:799', '00:01:29:910'), ('00:01:29:910', '00:01:37:560'), ('00:01:37:560', '00:01:46:190'), ('00:01:46:190', '00:01:53:600'), ('00:01:53:600', '00:02:02:590'), ('00:02:02:590', '00:02:08:239'), ('00:02:08:239', '00:02:17:390'), ('00:02:17:390', '00:02:24:480'), ('00:02:24:480', '00:02:34:110'), ('00:02:34:110', '00:02:40:760'), ('00:02:40:760', '00:02:48:430'), ('00:02:48:430', '00:02:55:159'), ('00:02:55:159', '00:03:02:309'), ('00:03:02:309', '00:03:07:840'), ('00:03:07:840', '00:03:17:630'), ('00:03:17:630', '00:03:23:560'), ('00:03:23:560', '00:03:30:670'), ('00:03:30:670', '00:03:35:760'), ('00:03:35:760', '00:03:43:670'), ('00:03:43:670', '00:03:48:400'), ('00:03:48:400', '00:03:56:110'), ('00:03:56:110', '00:04:00:640'), ('00:04:00:640', '00:04:08:949'), ('00:04:08:949', '00:04:15:000'), ('00:04:15:000', '00:04:22:069'), ('00:04:22:069', '00:04:29:680'), ('00:04:29:680', '00:04:37:629'), ('00:04:37:629', '00:04:44:120'), ('00:04:44:120', '00:04:52:189'), ('00:04:52:189', '00:04:58:720'), ('00:04:58:720', '00:05:07:469'), ('00:05:07:469', '00:05:13:880'), ('00:05:13:880', '00:05:21:830'), ('00:05:21:830', '00:05:27:960'), ('00:05:27:960', '00:05:37:830'), ('00:05:37:830', '00:05:44:360'), ('00:05:44:360', '00:05:52:550'), ('00:05:52:550', '00:05:58:960'), ('00:05:58:960', '00:06:07:110'), ('00:06:07:110', '00:06:12:639'), ('00:06:12:639', '00:06:20:270'), ('00:06:20:270', '00:06:25:919'), ('00:06:25:919', '00:06:34:110'), ('00:06:34:110', '00:06:39:880'), ('00:06:39:880', '00:06:50:110'), ('00:06:50:110', '00:06:56:240'), ('00:06:56:240', '00:07:05:510'), ('00:07:05:510', '00:07:12:160'), ('00:07:12:160', '00:07:21:550'), ('00:07:21:550', '00:07:28:560'), ('00:07:28:560', '00:07:36:510'), ('00:07:36:510', '00:07:43:400'), ('00:07:43:400', '00:07:51:790'), ('00:07:51:790', '00:07:58:319'), ('00:07:58:319', '00:08:06:189'), ('00:08:06:189', '00:08:13:039'), ('00:08:13:039', '00:08:21:070'), ('00:08:21:070', '00:08:27:240'), ('00:08:27:240', '00:08:35:909'), ('00:08:35:909', '00:08:43:000'), ('00:08:43:000', '00:08:51:590'), ('00:08:51:590', '00:08:57:519'), ('00:08:57:519', '00:09:06:509'), ('00:09:06:509', '00:09:13:680'), ('00:09:13:680', '00:09:21:310'), ('00:09:21:310', '00:09:27:440'), ('00:09:27:440', '00:09:36:590'), ('00:09:36:590', '00:09:42:160'), ('00:09:42:160', '00:09:51:470'), ('00:09:51:470', '00:09:58:839'), ('00:09:58:839', '00:10:08:110'), ('00:10:08:110', '00:10:16:120'), ('00:10:16:120', '00:10:23:750'), ('00:10:23:750', '00:10:30:160'), ('00:10:30:160', '00:10:39:030'), ('00:10:39:030', '00:10:47:120'), ('00:10:47:120', '00:10:55:550'), ('00:10:55:550', '00:11:01:320'), ('00:11:01:320', '00:11:08:590'), ('00:11:08:590', '00:11:14:240'), ('00:11:14:240', '00:11:22:629'), ('00:11:22:629', '00:11:27:680'), ('00:11:27:680', '00:11:35:230'), ('00:11:35:230', '00:11:42:600'), ('00:11:42:600', '00:11:50:870'), ('00:11:50:870', '00:11:55:240'), ('00:11:55:240', '00:12:03:670'), ('00:12:03:670', '00:12:09:279'), ('00:12:09:279', '00:12:17:189'), ('00:12:17:189', '00:12:24:160'), ('00:12:24:160', '00:12:33:670'), ('00:12:33:670', '00:12:38:959'), ('00:12:38:959', '00:12:46:069'), ('00:12:46:069', '00:12:52:399'), ('00:12:52:399', '00:12:58:870'), ('00:12:58:870', '00:13:05:600'), ('00:13:05:600', '00:13:14:350'), ('00:13:14:350', '00:13:22:199'), ('00:13:22:199', '00:13:31:509'), ('00:13:31:509', '00:13:38:279'), ('00:13:38:279', '00:13:46:069'), ('00:13:46:069', '00:13:52:959'), ('00:13:52:959', '00:14:00:790'), ('00:14:00:790', '00:14:06:639'), ('00:14:06:639', '00:14:16:350'), ('00:14:16:350', '00:14:22:199'), ('00:14:22:199', '00:14:29:430'), ('00:14:29:430', '00: ...

# %% [markdown]
# VTT SPLITTING

# %%
import re
from datetime import timedelta

def parse_vtt_time(time_str):
    """Convert a VTT time string to a timedelta."""
    hours, minutes, seconds,milliseconds = map(float, re.split('[:.]', time_str))
    return timedelta(hours=hours, minutes=minutes, seconds=seconds, milliseconds=milliseconds)

def split_vtt_by_timestamps(vtt_content, splits):
    """Split VTT content based on given start and end timestamps."""
    lines = vtt_content.split('\n')
    split_contents = [[] for _ in splits]
    current_split_index = 0
    start_time = None

    for line in lines:
        if '-->' in line:
            start_time_str, end_time_str = re.findall(r'\d{2}:\d{2}:\d{2}\.\d{3}', line)
            start_time = parse_vtt_time(start_time_str)
            # Check if the current caption falls within the current split range
            if start_time >= splits[current_split_index][1]:
                current_split_index += 1
            if current_split_index >= len(splits):
                break  # All splits are processed
        if start_time is not None and current_split_index < len(splits) and start_time >= splits[current_split_index][0]:
            split_contents[current_split_index].append(line)

    return split_contents

def write_splits_to_files(split_contents):
    """Write each split content to a separate VTT file."""
    for i, content in enumerate(split_contents):
        with open(f'split_{i+1}.vtt', 'w') as f:
            f.write('WEBVTT\nKind: captions\nLanguage: en\n\n')
            f.write('\n'.join(content))

def process_vtt_file(file_path, splits):
    """Read VTT file, split by timestamps, and write to separate files."""
    with open(file_path, 'r') as file:
        vtt_content = file.read()
    split_contents = split_vtt_by_timestamps(vtt_content, splits)
    write_splits_to_files(split_contents)

file_path = 'subtitles/6dKiEY0UOtA.en.vtt'

splits = []
for i in time_format:
    splits.append((parse_vtt_time(i[0]), parse_vtt_time(i[1])))

process_vtt_file(file_path, splits)

# %%
def write_splits_to_files(split_contents, output_folder):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    for i, content in enumerate(split_contents):
        file_path = os.path.join(output_folder, f'split_{i+1}.vtt')
        with open(file_path, 'w') as f:
            f.write('WEBVTT\nKind: captions\nLanguage: en\n\n')
            f.write('\n'.join(content))

def process_vtt_file(file_path, splits, output_folder):
    with open(file_path, 'r') as file:
        vtt_content = file.read()
    split_contents = split_vtt_by_timestamps(vtt_content, splits)
    write_splits_to_files(split_contents, output_folder)

import os

file_path = 'subtitles/6dKiEY0UOtA.en.vtt'
output_folder = 'subtitles_splits' 

splits = []
for i in time_format:
    splits.append((parse_vtt_time(i[0]), parse_vtt_time(i[1])))

process_vtt_file(file_path, splits, output_folder)

# %% [markdown]
# EXTRACTING THE TEXT FROM THE VTT FILE

# %%
import re

def extract_specific_lines(vtt_filename):
    # Regular expression to match lines with text, timestamps, and formatting tags
    pattern = re.compile(r'.*<\d{2}:\d{2}:\d{2}\.\d{3}><c>.*</c>.*')
    
    with open(vtt_filename, 'r', encoding='utf-8') as file:
        for line in file:
            if re.match(pattern, line):
                print(line.strip())


vtt_filename = 'subtitles_splits/split_171.vtt'
extract_specific_lines(vtt_filename)

def extract_text_from_vtt_line(line):
    # Remove all occurrences of timestamp and formatting tags
    text_only = re.sub(r'<\d{2}:\d{2}:\d{2}\.\d{3}>|<c>|</c>', '', line)
    return text_only

# Example usage
vtt_line = "you<00:21:06.960><c> get</c><00:21:07.280><c> but</c><00:21:07.440><c> it's</c><00:21:07.679><c> also</c><00:21:07.919><c> a</c><00:21:08.039><c> great</c><00:21:08.280><c> way</c><00:21:08.400><c> to</c>"
text_only = extract_text_from_vtt_line(vtt_line)
print(text_only)
# Out:
# you<00:21:06.960><c> get</c><00:21:07.280><c> but</c><00:21:07.440><c> it's</c><00:21:07.679><c> also</c><00:21:07.919><c> a</c><00:21:08.039><c> great</c><00:21:08.280><c> way</c><00:21:08.400><c> to</c>
# support<00:21:09.000><c> independent</c><00:21:09.600><c> creators</c><00:21:10.400><c> too</c><00:21:11.039><c> thanks</c>
# for<00:21:11.480><c> watching</c><00:21:11.840><c> and</c><00:21:12.080><c> maybe</c><00:21:12.360><c> next</c><00:21:12.600><c> time</c><00:21:12.799><c> you'll</c>
# be<00:21:13.159><c> watching</c><00:21:13.440><c> early</c><00:21:14.080><c> on</c><00:21:14.559><c> nebula</c>

# %%
import re

def extract_specific_lines(vtt_filename):
    # Regular expression to match lines with text, timestamps, and formatting tags
    pattern = re.compile(r'.*<\d{2}:\d{2}:\d{2}\.\d{3}><c>.*</c>.*')
    
    extracted_lines = "" 
    
    with open(vtt_filename, 'r', encoding='utf-8') as file:
        for line in file:
            if re.match(pattern, line):
                extracted_lines += line.strip() + "\n" 
    
    return extracted_lines

vtt_filename = 'subtitles_splits/split_1.vtt'
extracted_text = extract_specific_lines(vtt_filename)

def extract_text_from_vtt_line(line):
    # Remove all occurrences of timestamp and formatting tags
    text_only = re.sub(r'<\d{2}:\d{2}:\d{2}\.\d{3}>|<c>|</c>', '', line)
    return text_only

text_only = extract_text_from_vtt_line(extracted_text)
print(text_only)
# Out:
# Tokyo has a lot of trains and that's an
# understatement so you might think that
# with 14 Rail and Metro lines and shin
# kanen high-speed trains departing every

# %% [markdown]
# EXTRACTING LINKS OF YOUTUBE VIDEOS

# %%
import subprocess
import json

def get_youtube_urls(channel_url):
    command = ['yt-dlp', '-j', '--flat-playlist', channel_url]
    
    result = subprocess.run(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
    if result.returncode != 0:
        print("Error:", result.stderr)
        return []
    
    video_urls = []
    for line in result.stdout.strip().split('\n'):
        video_data = json.loads(line)
        video_url = f"https://www.youtube.com/watch?v={video_data['id']}"
        video_urls.append(video_url)
    
    return video_urls

channel_url = 'https://www.youtube.com/@NotJustBikes/videos'
video_urls = get_youtube_urls(channel_url)
for url in video_urls:
    print(url)
# Out:
# https://www.youtube.com/watch?v=hTPIs370dPM
# https://www.youtube.com/watch?v=6dKiEY0UOtA
# https://www.youtube.com/watch?v=JRbnBc-97Ps
# https://www.youtube.com/watch?v=g0F_hTGYa0Y
# https://www.youtube.com/watch?v=6FwQp0xnFEE
# https://www.youtube.com/watch?v=CHZwOAIect4
# https://www.youtube.com/watch?v=_yDtLv-7xZ4
# https://www.youtube.com/watch?v=6Vil5KC7Bl0
# https://www.youtube.com/watch?v=HACaRm2KP6Q
# https://www.youtube.com/watch?v=ztpcWUqVpIg
# https://www.youtube.com/watch?v=AOc8ASeHYNw
# https://www.youtube.com/watch?v=ymcBC7MFRIk
# https://www.youtube.com/watch?v=REni8Oi1QJQ
# https://www.youtube.com/watch?v=8nZh7A7qTPo
# https://www.youtube.com/watch?v=zmp09Fd07oc
# https://www.youtube.com/watch?v=kdz6FeQLuHQ
# https://www.youtube.com/watch?v=jN7mSXMruEo
# https://www.youtube.com/watch?v=EqwasBTzZS8
# https://www.youtube.com/watch?v=n94-_yE4IeU
# https://www.youtube.com/watch?v=mXLqrMljdfU
# https://www.youtube.com/watch?v=VvdQ381K5xg
# https://www.youtube.com/watch?v=VpavEMVQpW8
# https://www.youtube.com/watch?v=KkO-DttA9ew
# https://www.youtube.com/watch?v=_ByEBjf9ktY
# https://www.youtube.com/watch?v=rQhzEnWCgHA
# https://www.youtube.com/watch?v=muPcHs-E4qc
# https://www.youtube.com/watch?v=pWnreLG_cvc
# https://www.youtube.com/watch?v=MnyeRlMsTgI
# https://www.youtube.com/watch?v=oHlpmxLTxpw
# https://www.youtube.com/watch?v=OQE_5MFCekg
# https://www.youtube.com/watch?v=KPUlgSRn6e0
# https://www.youtube.com/watch?v=SDXB0CY2tSQ
# https://www.youtube.com/watch?v=VWDFgzAjr1k
# https://www.youtube.com/watch?v=7Nw6qyyrTeI
# https://www.youtube.com/watch?v=cO6txCZpbsQ
# https://www.youtube.com/watch?v=sI-1YNAmWlk
# https://www.youtube.com/watch?v=IbFGG4T3_Yo
# https://www.youtube.com/watch?v=d8RRE2rDw4k
# https://www.youtube.com/watch?v=Ds-v2-qyCc8
# https://www.youtube.com/watch?v=vxWjtpzCIfA
# https://www.youtube.com/watch?v=bglWCuCMSWc
# https://www.youtube.com/watch?v=M8F5hXqS-Ac
# https://www.youtube.com/watch?v=uxykI30fS54
# https://www.youtube.com/watch?v=aM9Q5x6dM7w
# https://www.youtube.com/watch?v=CTV-wwszGw8
# https://www.youtube.com/watch?v=1fdxILdMk30
# https://www.youtube.com/watch?v=OObwqreAJ48
# https://www.youtube.com/watch?v=MWsGBRdK2N0
# https://www.youtube.com/watch?v=ORzNZUeUHAM
# https://www.youtube.com/watch?v=XfQUOHlAocY
# https://www.youtube.com/watch?v=qSW5xy_kg9E
# https://www.youtube.com/watch?v=CCOdQsZa15o
# https://www.youtube.com/watch?v=Mxvk3KO8p20
# https://www.youtube.com/watch?v=xB1tgkOM6Bw
# https://www.youtube.com/watch?v=aESqrP3hfi8
# https://www.youtube.com/watch?v=g95IzRUAAh0
# https://www.youtube.com/watch?v=Uhx-26GfCBU
# https://www.youtube.com/watch?v=7IsMeKl-Sv0
# https://www.youtube.com/watch?v=nXexT_G8hwI
# https://www.youtube.com/watch?v=hGnt5YhEu4E
# https://www.youtube.com/watch?v=VVUeqxXwCA0
# https://www.youtube.com/watch?v=y_SXXTBypIg
# https://www.youtube.com/watch?v=vMed1qceJ_Q
# https://www.youtube.com/watch?v=c1l75QqRR48
# https://www.youtube.com/watch?v=22ovt1EMULY
# https://www.youtube.com/watch?v=PgFVjCL21WI
# https://www.youtube.com/watch?v=knbVWXzL4-4
# https://www.youtube.com/watch?v=n1G0Lyh3uik
# https://www.youtube.com/watch?v=bnKIVX968PQ
# https://www.youtube.com/watch?v=bMJaMy-0ChA
# https://www.youtube.com/watch?v=B9ly7JjqEb0
# https://www.youtube.com/watch?v=Ra_0DgnJ1uQ
# https://www.youtube.com/watch?v=9HdqTZs3vjU
# https://www.youtube.com/watch?v=1UxCbmT9elk
# https://www.youtube.com/watch?v=5iFlWteKVlY
# https://www.youtube.com/watch?v=CgvYgxo6UY8
# https://www.youtube.com/watch?v=HjzzV2Akyds
# https://www.youtube.com/watch?v=RQY6WGOoYis
# https://www.youtube.com/watch?v=bAxRYrpbnuA
# https://www.youtube.com/watch?v=56b5cI2qtYQ
# https://www.youtube.com/watch?v=42oQN7fy_eM
# https://www.youtube.com/watch?v=0JtoSafhvLM
# https://www.youtube.com/watch?v=ybFG-GyS_38
# https://www.youtube.com/watch?v=9OfBpQgLXUc
# https://www.youtube.com/watch?v=GlXNVnftaNs
# https://www.youtube.com/watch?v=Y0ntJ8DM8-8
# https://www.youtube.com/watch?v=kYHTzqHIngk
# https://www.youtube.com/watch?v=vI5pbDFDZyI
# https://www.youtube.com/watch?v=F4kmDxcfR48

# %% [markdown]
# BATCH PROCESSING FINAL CODE

# %%
import subprocess
import json
from pytube import YouTube
from pydub import AudioSegment
import os
import yt_dlp
from pydub import AudioSegment
import re
from datetime import datetime, timedelta

#Obataining the URLS for a Youtube Channel
def get_youtube_urls(channel_url):
    command = ['yt-dlp', '-j', '--flat-playlist', channel_url]
    
    result = subprocess.run(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
    if result.returncode != 0:
        print("Error:", result.stderr)
        return []
    
    video_urls = []
    for line in result.stdout.strip().split('\n'):
        video_data = json.loads(line)
        video_url = f"https://www.youtube.com/watch?v={video_data['id']}"
        video_urls.append(video_url)
    
    return video_urls

channel_url = 'https://www.youtube.com/@NotJustBikes/videos'
video_urls = get_youtube_urls(channel_url)

#Downloading the audio from the Youtube Channel into MP3 Format
def download_audio_from_youtube(video_url, output_path):
    try:
        yt = YouTube(video_url)
        video_stream = yt.streams.filter(only_audio=True).first()
        download_path = video_stream.download(output_path=output_path)

        audio = AudioSegment.from_file(download_path)
        mp3_path = os.path.splitext(download_path)[0] + '.mp3'
        audio.export(mp3_path, format="mp3")

        os.remove(download_path)

        print(f"Downloaded and converted audio saved at: {mp3_path}")
    except Exception as e:
        print(f"An error occurred: {e}")

i = 0 
for video_url in video_urls:
    output_path = f"test{i}.mp3"
    download_audio_from_youtube(video_url, output_path)
    i += 1
count = i

#Obtaining the VTT Subtitle files for the Youtube Videos
def extract_transcript(video_url):
    ydl_opts = {
        'skip_download': True, 
        'writeautomaticsub': True, 
        'subtitleslangs': ['en','en-CA'],  
        'subtitlesformat': 'vtt',  
        'outtmpl': 'subtitles/%(id)s.%(ext)s',  
        'quiet': True, 
    }

    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        ydl.download([video_url])

for video_url in video_urls:
    extract_transcript(video_url)

#Getting the timestamp splits, Splitting VTT functions
def parse_vtt_time(time_str):
    """Convert a VTT time string to a timedelta."""
    hours, minutes, seconds,milliseconds = map(float, re.split('[:.]', time_str))
    return timedelta(hours=hours, minutes=minutes, seconds=seconds, milliseconds=milliseconds)

def split_vtt_by_timestamps(vtt_content, splits):
    """Split VTT content based on given start and end timestamps."""
    lines = vtt_content.split('\n')
    split_contents = [[] for _ in splits]
    current_split_index = 0
    start_time = None

    for line in lines:
        if '-->' in line:
            start_time_str, end_time_str = re.findall(r'\d{2}:\d{2}:\d{2}\.\d{3}', line)
            start_time = parse_vtt_time(start_time_str)
            # Check if the current caption falls within the current split range
            if start_time >= splits[current_split_index][1]:
                current_split_index += 1
            if current_split_index >= len(splits):
                break  # All splits are processed
        if start_time is not None and current_split_index < len(splits) and start_time >= splits[current_split_index][0]:
            split_contents[current_split_index].append(line)

    return split_contents

def write_splits_to_files(split_contents, output_folder):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    for i, content in enumerate(split_contents):
        file_path = os.path.join(output_folder, f'split_{i+1}.vtt')
        with open(file_path, 'w') as f:
            f.write('WEBVTT\nKind: captions\nLanguage: en\n\n')
            f.write('\n'.join(content))

def process_vtt_file(file_path, splits, output_folder):
    with open(file_path, 'r') as file:
        vtt_content = file.read()
    split_contents = split_vtt_by_timestamps(vtt_content, splits)
    write_splits_to_files(split_contents, output_folder)

def chunk_audio_files(timestamps, output_folder):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    for file, chunks in timestamps.items():
        audio = AudioSegment.from_file(file)
        for i, (start, end) in enumerate(chunks):
            chunk = audio[start:end]
            chunk_filename = os.path.join(output_folder, f"{os.path.basename(file).rsplit('.', 1)[0]}_chunk{i}.mp3")
            chunk.export(chunk_filename, format="mp3")
            print(f"Exported {chunk_filename}")

def extract_timestamps_from_vtt(filename):
    timestamp_regex = r'(\d{2}:\d{2}:\d{2}\.\d{3}) --> (\d{2}:\d{2}:\d{2}\.\d{3})'
    
    timestamps = []
    
    with open(filename, 'r', encoding='utf-8') as file:
        content = file.read()
        matches = re.findall(timestamp_regex, content)
        for start, end in matches:
            start_ms = int(timedelta(hours=int(start[0:2]), minutes=int(start[3:5]), seconds=int(start[6:8]), milliseconds=int(start[9:])).total_seconds() * 1000)
            end_ms = int(timedelta(hours=int(end[0:2]), minutes=int(end[3:5]), seconds=int(end[6:8]), milliseconds=int(end[9:])).total_seconds() * 1000)
            timestamps.append((start_ms, end_ms))
    return timestamps

def combine_timestamps(timestamps):
    combined_timestamps = []
    i = 0
    while i < len(timestamps) - 6:
        combined_timestamps.append((timestamps[i][0], timestamps[i + 6][1]))
        i += 7
    while i < len(timestamps):
        combined_timestamps.append(timestamps[i])
        i += 1
    return combined_timestamps

def milliseconds_to_time_format(milliseconds):
    # Calculate hours, minutes, seconds and milliseconds
    hours = milliseconds // (1000 * 60 * 60)
    milliseconds_remaining = milliseconds % (1000 * 60 * 60)
    minutes = milliseconds_remaining // (1000 * 60)
    milliseconds_remaining %= (1000 * 60)
    seconds = milliseconds_remaining // 1000
    milliseconds_remaining %= 1000
    
    # Format the time string
    time_format = f"{hours:02}:{minutes:02}:{seconds:02}:{milliseconds_remaining:03}"
    
    return time_format

#Chunking the audio files and splitting the VTT files
j=0
for filename in os.listdir('subtitles'):
    timestamps = extract_timestamps_from_vtt(os.path.join('subtitles',filename))
    arr = timestamps
    combined_timestamps = combine_timestamps(arr)
    #print(timestamps)
    for i in range(0,count):
        timestamps = {
            f'test{i}.mp3/test{i}.mp3': combined_timestamps}
        output_folder = f'final_outputs/output{i}'
        chunk_audio_files(timestamps, output_folder)
    # Splitting the VTT files
    splits = []
    time_format = []
    for k in combined_timestamps:
        start_format = milliseconds_to_time_format(i[0])
        end_format = milliseconds_to_time_format(i[1])
        time_format.append((start_format, end_format))
    for i in time_format:
        splits.append((parse_vtt_time(i[0]), parse_vtt_time(i[1])))
    process_vtt_file(os.path.join('subtitles',filename), splits,f'subtitles_split{j}')
    j = j+1

#Text Extraction from the VTT files and storing it into a text file
def extract_specific_lines(vtt_filename):
    pattern = re.compile(r'.*<\d{2}:\d{2}:\d{2}\.\d{3}><c>.*</c>.*')
    
    with open(vtt_filename, 'r', encoding='utf-8') as file:
        for line in file:
            if re.match(pattern, line):
                print(line.strip())

def extract_text_from_vtt_line(line):
    text_only = re.sub(r'<\d{2}:\d{2}:\d{2}\.\d{3}>|<c>|</c>', '', line)
    return text_only

matching_directories = []
for item in os.listdir('.'):
    if os.path.isdir(item) and 'subtitles_split' in item:
        matching_directories.append(item)

for filedir in matching_directories:
    for file in matching_directories:
        extracted_text = extract_specific_lines(os.path.join(filedir,file))
        text_only = extract_text_from_vtt_line(extracted_text)
        file_path = f'{filedir}/{file}.txt'
        with open(file_path, 'w', encoding='utf-8') as file:
            file.write(text_only)
